# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from urllib.request import urlopen, HTTPError, URLError
from urllib.parse import urlparse
import re
from concurrent.futures import ThreadPoolExecutor, TimeoutError
from bs4 import BeautifulSoup
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import random


# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

import warnings
warnings.filterwarnings('ignore')

# %%
# defino las paletas de colores que usaremos
color_palette = sns.hls_palette(20, l=0.35, s=1)
total_color = color_palette[15]
normal_color = color_palette[9]
disaster_color = color_palette[1]
links_color = color_palette[2]
no_links_color = color_palette[11]
color_palette = sns.palplot(color_palette)

# %%
def is_not_nan(value):
    return value == value

# %%
twt_data = pd.read_csv('../../../DataSets/twt_train.csv')

# %%
twt_data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
twt_data.describe()
# Out:
#                         id               target
# count             7,613.00             7,613.00
# mean              5,441.93                 0.43
# std               3,137.12                 0.50
# min                   1.00                 0.00
# 25%               2,734.00                 0.00
# 50%               5,408.00                 0.00
# 75%               8,146.00                 1.00
# max              10,873.00                 1.00

# %%
twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 208.2+ KB

# %%
def obtain_link(twt):
    url = re.search("(?P<url>https?://[^\s]+)", twt)
    return url.group("url") if url else np.NaN

# %%
twt_data['link'] = twt_data['text'].map(obtain_link)
twt_data
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#                         link
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 7608  http://t.co/STfMbbZFB5
# 7609                     NaN
# 7610  http://t.co/zDtoyd8EbJ
# 7611                     NaN
# 7612  http://t.co/YmY4rSkQ3d
#
# [7613 rows x 6 columns]

# %%
twt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
#  5   link      3971 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 238.0+ KB

# %%
def isShorted(link):
    if link != link: return np.NaN 
    return 't.co' in str(link)

# %%
twt_data['link_shorted'] = twt_data['link'].map(isShorted)

# %%
twt_data['for_graphics'] = 1
grouped_twt = twt_data.groupby('target').sum().reset_index()
g = sns.barplot(x='target', y='for_graphics', data=grouped_twt, palette=[normal_color, disaster_color])
for index, row in grouped_twt.iterrows():
    g.text(row.target, row.for_graphics, row.for_graphics, color='black', ha="center")
g.set_title("Cantidad de tweets segun su target", fontsize=16, pad=20)
g.set_xlabel("Refieren a un Desastre", fontsize=14)
g.set_ylabel("Cantidad", fontsize=14)
g.set_xticklabels(['No', 'Si'])
# Out:
# [Text(0, 0, 'No'), Text(0, 0, 'Si')]

# %%
twt_data['with_link'] = twt_data['link'].map(is_not_nan)
grouped_twt = twt_data.groupby('with_link').sum().reset_index()
g = sns.barplot(x='with_link', y='for_graphics', data=grouped_twt, palette=[no_links_color, links_color])
for index, row in grouped_twt.iterrows():
    g.text(row.name, row.for_graphics, row.for_graphics, color='black', ha="center")
g.set_title("Cantidad de tweets segun la existencia de links", fontsize=16, pad=20)
g.set_xlabel("Tiene link", fontsize=14)
g.set_ylabel("Cantidad", fontsize=14)
g.set_xticklabels(['No', 'Si'])
# Out:
# [Text(0, 0, 'No'), Text(0, 0, 'Si')]

# %%
grouped_twt = twt_data.groupby(['target', 'with_link']).sum().reset_index()
grouped_twt.loc[grouped_twt['with_link']==False, 'with_link'] = 'No'
grouped_twt.loc[grouped_twt['with_link']==True, 'with_link'] = 'Si'
g = sns.barplot(x='target', y='for_graphics', hue='with_link', data=grouped_twt, palette=[no_links_color, links_color])
g.set_title("Cantidad de tweets segun su target y si tiene link", fontsize=16, pad=20)
g.set_xlabel("Refiere a un Desastre", fontsize=14)
g.set_ylabel("Cantidad", fontsize=14)
g.set_xticklabels(['No', 'Si'])
g.legend(title="Tiene Link?")

# %%
grouped_by_target_twt = twt_data.groupby(['target']).sum().reset_index()
grouped_by_links_twt = twt_data.groupby(['target', 'with_link']).sum().reset_index()
grouped_by_links_twt.loc[grouped_by_links_twt['with_link'] == False, 'for_graphics'] = grouped_by_target_twt['for_graphics'].tolist()
grouped_by_links_twt.loc[grouped_by_links_twt['with_link'] == False, 'with_link'] = 'Total'
grouped_by_links_twt.loc[grouped_by_links_twt['with_link'] == True, 'with_link'] = 'Tiene link'
grouped_by_links_twt
# Out:
#    target   with_link        id  for_graphics
# 0       0       Total  13588868          4342
# 1       0  Tiene link   9321462          1799
# 2       1       Total   5894662          3271
# 3       1  Tiene link  12624458          2172

# %%
g = sns.barplot(x = 'target', y = 'for_graphics', data=grouped_by_links_twt, hue='with_link', palette=[total_color, links_color])
g.set_title("Comparacion de la cantidad de tweets total y los que tienen link", fontsize=16, pad=20)
g.set_xlabel("Refiere a un Desastre", fontsize=14)
g.set_ylabel("Cantidad", fontsize=14)
g.set_xticklabels(['No', 'Si'])
g.legend(title="")

# %%
grouped_twt = twt_data.groupby('target').sum().reset_index()
g = sns.barplot(x = 'target', y = 'for_graphics', data=grouped_by_links_twt, hue='with_link',\
                palette=[total_color, links_color], dodge=False)
g.set_title("Comparacion de la cantidad de tweets total y los que tienen link", fontsize=16, pad=20)
g.set_xlabel("Refiere a un Desastre", fontsize=14)
g.set_ylabel("Cantidad", fontsize=14)
g.set_xticklabels(['No', 'Si'])
g.legend(title="")
for index, row in grouped_twt.iterrows():
    g.text(row.target, row.for_graphics, row.for_graphics, color='black', ha="center")
    g.text(row.target, row.with_link, row.with_link, color='black', ha="center", va='top')

# %% [markdown]
# ## A continuacion trabajaremos exclusivamente con los twits que poseen links

# %%
twt_data_with_links = twt_data.dropna(subset=['link'])
twt_data_with_links = twt_data_with_links[twt_data_with_links['link_shorted']]
twt_data_with_links
# Out:
#          id keyword                       location  \
# 31       48  ablaze                     Birmingham
# 32       49  ablaze  Est. September 2012 - Bristol
# 33       50  ablaze                         AFRICA
# 35       53  ablaze                     London, UK
# 37       55  ablaze                   World Wide!!
# ...     ...     ...                            ...
# 7606  10866     NaN                            NaN
# 7607  10867     NaN                            NaN
# 7608  10869     NaN                            NaN
# 7610  10871     NaN                            NaN
# 7612  10873     NaN                            NaN
#
#                                                    text  target  \
# 31    @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 32    We always try to bring the heavy. #metal #RT h...       0
# 33    #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 35    On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 37    INEC Office in Abia Set Ablaze - http://t.co/3...       1
# ...                                                 ...     ...
# 7606  Suicide bomber kills 15 in Saudi security site...       1
# 7607  #stormchase Violent Record Breaking EF-5 El Re...       1
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#                         link link_shorted  for_graphics  with_link
# 31    http://t.co/lHYXEOHY6C         True             1       True
# 32    http://t.co/YAo1e0xngw         True             1       True
# 33    http://t.co/2nndBGwyEi         True             1       True
# 35    http://t.co/qqsmshaJ3N         True             1       True
# 37    http://t.co/3ImaomknnA         True             1       True
# ...                      ...          ...           ...        ...
# 7606  http://t.co/nF4IculOje         True             1       True
# 7607  http://t.co/3SICroAaNz         True             1       True
# 7608  http://t.co/STfMbbZFB5         True             1       True
# 7610  http://t.co/zDtoyd8EbJ         True             1       True
# 7612  http://t.co/YmY4rSkQ3d         True             1       True
#
# [3968 rows x 9 columns]

# %%
twt_data_with_links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3968 entries, 31 to 7612
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            3968 non-null   int64
#  1   keyword       3948 non-null   object
#  2   location      2714 non-null   object
#  3   text          3968 non-null   object
#  4   target        3968 non-null   int64
#  5   link          3968 non-null   object
#  6   link_shorted  3968 non-null   object
#  7   for_graphics  3968 non-null   int64
#  8   with_link     3968 non-null   bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 205.4+ KB

# %%
twt_data_with_links['real_link'] = 'np.NaN'
twt_data_with_links['error'] = 'np.NaN'
twt_data_with_links['page'] = 'np.NaN'
twt_data_with_links = twt_data_with_links.reset_index()
twt_data_with_links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3968 entries, 0 to 3967
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         3968 non-null   int64
#  1   id            3968 non-null   int64
#  2   keyword       3948 non-null   object
#  3   location      2714 non-null   object
#  4   text          3968 non-null   object
#  5   target        3968 non-null   int64
#  6   link          3968 non-null   object
#  7   link_shorted  3968 non-null   object
#  8   for_graphics  3968 non-null   int64
#  9   with_link     3968 non-null   bool
#  10  real_link     3968 non-null   object
#  11  error         3968 non-null   object
#  12  page          3968 non-null   object
# dtypes: bool(1), int64(4), object(8)
# memory usage: 251.9+ KB

# %%
def obtain_real_link(index, url):
    try:
        with urlopen(url, timeout = 20) as response:
            actual_url = response.geturl()
            error = np.NaN
            page = response.read()
    except HTTPError as e:
        actual_url = e.url
        error = e
        page = np.NaN
    except URLError as e:
        actual_url = url
        error = e
        page = np.NaN
    except:
        actual_url = url
        error = 'OTHER_ERROR'
        page = np.NaN
    return (index, actual_url, error, page)

# %%
def doWork(row):
    return obtain_real_link(row[0], row[1]['link'])

# %% [raw]
# # con esta pieza de codigo obtenemos los links reales y las paginas de forma paralelizada
# init = 0
# index = -1
# retry = 0
# with ThreadPoolExecutor(max_workers=200) as pool:
#     while True:
#         try:
#             for result in pool.map(doWork, twt_data_with_links.loc[init:].iterrows(), timeout=110):
#                 index = result[0]
#                 twt_data_with_links['real_link'][index] = result[1]
#                 twt_data_with_links['error'][index] = result[2]
#                 twt_data_with_links['page'][index] = result[3]
#                 retry = 0
#             break
#         except TimeoutError
#             if (retry == 2):
#                 retry == 0
#                 init = init + 1
#             else:
#                 retry = retry + 1
#                 init = index + 1
#         except KeyboardInterrupt:
#             print('Terminado por el usuario')

# %% [raw]
# twt_data_with_links['error_code'] = twt_data_with_links['error'].map(lambda x: x.status if isinstance(x, HTTPError) else np.NaN)

# %% [raw]
# twt_data_with_links.to_csv('../../../DataSets/twt_with_links.csv')

# %%
twt_data_with_links = pd.read_csv('../../../DataSets/twt_with_links.csv').drop(columns=['Unnamed: 0'])
twt_data_with_links
# Out:
#          id keyword                       location  \
# 0        48  ablaze                     Birmingham
# 1        49  ablaze  Est. September 2012 - Bristol
# 2        50  ablaze                         AFRICA
# 3        53  ablaze                     London, UK
# 4        55  ablaze                   World Wide!!
# ...     ...     ...                            ...
# 3963  10866     NaN                            NaN
# 3964  10867     NaN                            NaN
# 3965  10869     NaN                            NaN
# 3966  10871     NaN                            NaN
# 3967  10873     NaN                            NaN
#
#                                                    text  target  \
# 0     @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 1     We always try to bring the heavy. #metal #RT h...       0
# 2     #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 3     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 4     INEC Office in Abia Set Ablaze - http://t.co/3...       1
# ...                                                 ...     ...
# 3963  Suicide bomber kills 15 in Saudi security site...       1
# 3964  #stormchase Violent Record Breaking EF-5 El Re...       1
# 3965  Two giant cranes holding a bridge collapse int...       1
# 3966  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 3967  The Latest: More Homes Razed by Northern Calif...       1
#
#                         link  link_shorted  \
# 0     http://t.co/lHYXEOHY6C          True
# 1     http://t.co/YAo1e0xngw          True
# 2     http://t.co/2nndBGwyEi          True
# 3     http://t.co/qqsmshaJ3N          True
# 4     http://t.co/3ImaomknnA          True
# ...                      ...           ...
# 3963  http://t.co/nF4IculOje          True
# 3964  http://t.co/3SICroAaNz          True
# 3965  http://t.co/STfMbbZFB5          True
# 3966  http://t.co/zDtoyd8EbJ          True
# 3967  http://t.co/YmY4rSkQ3d          True
#
#                                               real_link  \
# 0     https://twitter.com/dannypurewal/status/629284...
# 1     https://twitter.com/Valis_Ablaze/status/629274...
# 2     https://africanbaze.com/breaking-newsnigeria-f...
# 3     https://twitter.com/AnyOtherAnnaK/status/62919...
# 4     http://yabaleftonline.com/2015/08/inec-office-...
# ...                                                 ...
# 3963  https://www.reuters.com/article/us-saudi-secur...
# 3964                             http://t.co/3SICroAaNz
# 3965  https://gizmodo.com/two-giant-cranes-holding-a...
# 3966  https://earthquake.usgs.gov/earthquakes/eventp...
# 3967  https://abcnews.go.com/US/wireStory/latest-coo...
#
#                                                   error  \
# 0                             HTTP Error 404: Not Found
# 1                                                   NaN
# 2                             HTTP Error 404: Not Found
# 3                                                   NaN
# 4                             HTTP Error 403: Forbidden
# ...                                                 ...
# 3963                                                NaN
# 3964  <urlopen error [Errno -2] Name or service not ...
# 3965                                                NaN
# 3966                                                NaN
# 3967                          HTTP Error 404: Not Found
#
#                                                    page           error_code
# 0                                                   NaN               404.00
# 1     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 2                                                   NaN               404.00
# 3     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 4                                                   NaN               403.00
# ...                                                 ...                  ...
# 3963  b'<!--[if !IE]> This has been served from cach...                  nan
# 3964                                                NaN                  nan
# 3965  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
# 3966  b'<!doctype html>\n<html lang="en">\n\n<head>\...                  nan
# 3967                                                NaN               404.00
#
# [3968 rows x 11 columns]

# %%
twt_data_with_links.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3968 entries, 0 to 3967
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            3968 non-null   int64
#  1   keyword       3948 non-null   object
#  2   location      2714 non-null   object
#  3   text          3968 non-null   object
#  4   target        3968 non-null   int64
#  5   link          3968 non-null   object
#  6   link_shorted  3968 non-null   bool
#  7   real_link     3968 non-null   object
#  8   error         1758 non-null   object
#  9   page          2214 non-null   object
#  10  error_code    1386 non-null   float64
# dtypes: bool(1), float64(1), int64(2), object(7)
# memory usage: 205.4+ KB

# %%
twt_data_with_links['site'] = twt_data_with_links['real_link'].map(lambda x: urlparse(x).netloc)
twt_data_with_links
# Out:
#          id keyword                       location  \
# 0        48  ablaze                     Birmingham
# 1        49  ablaze  Est. September 2012 - Bristol
# 2        50  ablaze                         AFRICA
# 3        53  ablaze                     London, UK
# 4        55  ablaze                   World Wide!!
# ...     ...     ...                            ...
# 3963  10866     NaN                            NaN
# 3964  10867     NaN                            NaN
# 3965  10869     NaN                            NaN
# 3966  10871     NaN                            NaN
# 3967  10873     NaN                            NaN
#
#                                                    text  target  \
# 0     @bbcmtd Wholesale Markets ablaze http://t.co/l...       1
# 1     We always try to bring the heavy. #metal #RT h...       0
# 2     #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 3     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 4     INEC Office in Abia Set Ablaze - http://t.co/3...       1
# ...                                                 ...     ...
# 3963  Suicide bomber kills 15 in Saudi security site...       1
# 3964  #stormchase Violent Record Breaking EF-5 El Re...       1
# 3965  Two giant cranes holding a bridge collapse int...       1
# 3966  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 3967  The Latest: More Homes Razed by Northern Calif...       1
#
#                         link  link_shorted  \
# 0     http://t.co/lHYXEOHY6C          True
# 1     http://t.co/YAo1e0xngw          True
# 2     http://t.co/2nndBGwyEi          True
# 3     http://t.co/qqsmshaJ3N          True
# 4     http://t.co/3ImaomknnA          True
# ...                      ...           ...
# 3963  http://t.co/nF4IculOje          True
# 3964  http://t.co/3SICroAaNz          True
# 3965  http://t.co/STfMbbZFB5          True
# 3966  http://t.co/zDtoyd8EbJ          True
# 3967  http://t.co/YmY4rSkQ3d          True
#
#                                               real_link  \
# 0     https://twitter.com/dannypurewal/status/629284...
# 1     https://twitter.com/Valis_Ablaze/status/629274...
# 2     https://africanbaze.com/breaking-newsnigeria-f...
# 3     https://twitter.com/AnyOtherAnnaK/status/62919...
# 4     http://yabaleftonline.com/2015/08/inec-office-...
# ...                                                 ...
# 3963  https://www.reuters.com/article/us-saudi-secur...
# 3964                             http://t.co/3SICroAaNz
# 3965  https://gizmodo.com/two-giant-cranes-holding-a...
# 3966  https://earthquake.usgs.gov/earthquakes/eventp...
# 3967  https://abcnews.go.com/US/wireStory/latest-coo...
#
#                                                   error  \
# 0                             HTTP Error 404: Not Found
# 1                                                   NaN
# 2                             HTTP Error 404: Not Found
# 3                                                   NaN
# 4                             HTTP Error 403: Forbidden
# ...                                                 ...
# 3963                                                NaN
# 3964  <urlopen error [Errno -2] Name or service not ...
# 3965                                                NaN
# 3966                                                NaN
# 3967                          HTTP Error 404: Not Found
#
#                                                    page           error_code  \
# 0                                                   NaN               404.00
# 1     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 2                                                   NaN               404.00
# 3     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 4                                                   NaN               403.00
# ...                                                 ...                  ...
# 3963  b'<!--[if !IE]> This has been served from cach...                  nan
# 3964                                                NaN                  nan
# 3965  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
# 3966  b'<!doctype html>\n<html lang="en">\n\n<head>\...                  nan
# 3967                                                NaN               404.00
#
#                      site
# 0             twitter.com
# 1             twitter.com
# 2         africanbaze.com
# 3             twitter.com
# 4      yabaleftonline.com
# ...                   ...
# 3963      www.reuters.com
# 3964                 t.co
# 3965          gizmodo.com
# 3966  earthquake.usgs.gov
# 3967       abcnews.go.com
#
# [3968 rows x 12 columns]

# %%
twt_data_with_links['for_graphics'] = 1
grouped_by_sites = twt_data_with_links.groupby('site').sum()
grouped_by_sites
# Out:
#                                   id  target         link_shorted  \
# site
#                                21300       1                 4.00
# 1.usa.gov                     125663      13                15.00
# 1080plus.com                    1770       1                 1.00
# 1stheadlines.com               10628       1                 1.00
# 24x7freeadvice.wordpress.com    7843       0                 1.00
# ...                              ...     ...                  ...
# yournewswire.com               14239       1                 2.00
# youthsnews.com.au             275378      15                40.00
# zeenews.india.com              12563       2                 2.00
# ziprecruiter.com                2070       0                 1.00
# zkq.me                          4333       1                 1.00
#
#                                        error_code  for_graphics
# site
#                                              0.00             4
# 1.usa.gov                                6,060.00            15
# 1080plus.com                               403.00             1
# 1stheadlines.com                           403.00             1
# 24x7freeadvice.wordpress.com               410.00             1
# ...                                           ...           ...
# yournewswire.com                           806.00             2
# youthsnews.com.au                            0.00            40
# zeenews.india.com                          806.00             2
# ziprecruiter.com                           403.00             1
# zkq.me                                     410.00             1
#
# [1205 rows x 5 columns]

# %%
sites_top_20 = grouped_by_sites.sort_values('for_graphics', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'for_graphics', y = 'site', data=sites_top_20)
g.set_title("Top 20 de sitios mas linkeados a los tweets", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Sitios", fontsize=14)
# Out:
# Text(0, 0.5, 'Sitios')

# %% [markdown]
# ### Dejaremos afuera el sition t.co y las lineas que tienen como sitio twitter.com y su respuesta fue un error

# %%
def filter_twitter_error(row):
    return row.site != 't.co' and (row.site != 'twitter.com' or row.error != row.error)

# %%
filter_list = []
for index, row in twt_data_with_links.iterrows():
    filter_list.append(filter_twitter_error(row))
twt_data_with_links.loc[filter_list]
# Out:
#          id keyword                       location  \
# 1        49  ablaze  Est. September 2012 - Bristol
# 2        50  ablaze                         AFRICA
# 3        53  ablaze                     London, UK
# 4        55  ablaze                   World Wide!!
# 5        56  ablaze                            NaN
# ...     ...     ...                            ...
# 3962  10863     NaN                            NaN
# 3963  10866     NaN                            NaN
# 3965  10869     NaN                            NaN
# 3966  10871     NaN                            NaN
# 3967  10873     NaN                            NaN
#
#                                                    text  target  \
# 1     We always try to bring the heavy. #metal #RT h...       0
# 2     #AFRICANBAZE: Breaking news:Nigeria flag set a...       1
# 3     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 4     INEC Office in Abia Set Ablaze - http://t.co/3...       1
# 5     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# ...                                                 ...     ...
# 3962  #WorldNews Fallen powerlines on G:link tram: U...       1
# 3963  Suicide bomber kills 15 in Saudi security site...       1
# 3965  Two giant cranes holding a bridge collapse int...       1
# 3966  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 3967  The Latest: More Homes Razed by Northern Calif...       1
#
#                         link  link_shorted  \
# 1     http://t.co/YAo1e0xngw          True
# 2     http://t.co/2nndBGwyEi          True
# 3     http://t.co/qqsmshaJ3N          True
# 4     http://t.co/3ImaomknnA          True
# 5     http://t.co/wDUEaj8Q4J          True
# ...                      ...           ...
# 3962  http://t.co/EYSVvzA7Qm          True
# 3963  http://t.co/nF4IculOje          True
# 3965  http://t.co/STfMbbZFB5          True
# 3966  http://t.co/zDtoyd8EbJ          True
# 3967  http://t.co/YmY4rSkQ3d          True
#
#                                               real_link  \
# 1     https://twitter.com/Valis_Ablaze/status/629274...
# 2     https://africanbaze.com/breaking-newsnigeria-f...
# 3     https://twitter.com/AnyOtherAnnaK/status/62919...
# 4     http://yabaleftonline.com/2015/08/inec-office-...
# 5           https://www.youtube.com/watch?v=yG08hLEWzyM
# ...                                                 ...
# 3962      https://www.youtube.com/watch?v=yG08hLEWzyM&3
# 3963  https://www.reuters.com/article/us-saudi-secur...
# 3965  https://gizmodo.com/two-giant-cranes-holding-a...
# 3966  https://earthquake.usgs.gov/earthquakes/eventp...
# 3967  https://abcnews.go.com/US/wireStory/latest-coo...
#
#                           error  \
# 1                           NaN
# 2     HTTP Error 404: Not Found
# 3                           NaN
# 4     HTTP Error 403: Forbidden
# 5                           NaN
# ...                         ...
# 3962                        NaN
# 3963                        NaN
# 3965                        NaN
# 3966                        NaN
# 3967  HTTP Error 404: Not Found
#
#                                                    page           error_code  \
# 1     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 2                                                   NaN               404.00
# 3     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 4                                                   NaN               403.00
# 5     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# ...                                                 ...                  ...
# 3962  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3963  b'<!--[if !IE]> This has been served from cach...                  nan
# 3965  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
# 3966  b'<!doctype html>\n<html lang="en">\n\n<head>\...                  nan
# 3967                                                NaN               404.00
#
#                      site  for_graphics
# 1             twitter.com             1
# 2         africanbaze.com             1
# 3             twitter.com             1
# 4      yabaleftonline.com             1
# 5         www.youtube.com             1
# ...                   ...           ...
# 3962      www.youtube.com             1
# 3963      www.reuters.com             1
# 3965          gizmodo.com             1
# 3966  earthquake.usgs.gov             1
# 3967       abcnews.go.com             1
#
# [3455 rows x 13 columns]

# %%
sites_top_20_filtered = twt_data_with_links.loc[filter_list].groupby('site').sum()\
    .sort_values('for_graphics', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'for_graphics', y = 'site', data=sites_top_20_filtered)
g.set_title("Top 20 de sitios mas linkeados a los tweets", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Sitios", fontsize=14)
# Out:
# Text(0, 0.5, 'Sitios')

# %%
sites_top_20_filtered = twt_data_with_links.loc[filter_list].loc[twt_data_with_links['target']==1].groupby('site')\
    .sum().sort_values('for_graphics', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'for_graphics', y = 'site', data=sites_top_20_filtered)
g.set_title("Top 20 de sitios mas linkeados a los tweets referidos a un desastre", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Sitios", fontsize=14)
# Out:
# Text(0, 0.5, 'Sitios')

# %%
sites_top_20_filtered = twt_data_with_links.loc[filter_list].loc[twt_data_with_links['target']==0].groupby('site')\
    .sum().sort_values('for_graphics', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'for_graphics', y = 'site', data=sites_top_20_filtered)
g.set_title("Top 20 de sitios mas linkeados a los tweets que no se refieren a un desastre", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Sitios", fontsize=14)
# Out:
# Text(0, 0.5, 'Sitios')

# %%
sites = twt_data_with_links.loc[filter_list].loc[twt_data_with_links['target']==1].groupby('site')\
    .sum().reset_index()
g = sns.distplot(sites['for_graphics'], hist=True, kde=False, bins=20, color=disaster_color)
g.set_title('Frecuencia de la cantidad de veces que aparece un sitio durante un desastre',\
            fontsize=16, pad=20)
g.set_ylabel('Frecuencia', fontsize=18)
g.set_yscale('log')
g.set_xlabel('Cantidad de apariciones', fontsize=18)
# Out:
# Text(0.5, 0, 'Cantidad de apariciones')

# %%
sites = twt_data_with_links.loc[filter_list].loc[twt_data_with_links['target']==0].groupby('site')\
    .sum().reset_index()
g = sns.distplot(sites['for_graphics'], hist=True, kde=False, bins=20, color=normal_color)
g.set_title('Frecuencia de la cantidad de veces que aparece un sitio durante la normalidad',\
            fontsize=16, pad=20)
g.set_ylabel('Frecuencia', fontsize=18)
g.set_yscale('log')
g.set_xlabel('Cantidad de apariciones', fontsize=18)
# Out:
# Text(0.5, 0, 'Cantidad de apariciones')

# %% [markdown]
# ## A continuacion nos quedaremos exclusivamente con las lineas sin errores para analizar las paguinas

# %%
twt_data_without_error = twt_data_with_links.loc[twt_data_with_links['error'] != twt_data_with_links['error']]
twt_data_without_error
# Out:
#          id keyword                       location  \
# 1        49  ablaze  Est. September 2012 - Bristol
# 3        53  ablaze                     London, UK
# 5        56  ablaze                            NaN
# 6        59  ablaze                 Live On Webcam
# 7        64  ablaze                            NaN
# ...     ...     ...                            ...
# 3960  10859     NaN                            NaN
# 3962  10863     NaN                            NaN
# 3963  10866     NaN                            NaN
# 3965  10869     NaN                            NaN
# 3966  10871     NaN                            NaN
#
#                                                    text  target  \
# 1     We always try to bring the heavy. #metal #RT h...       0
# 3     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 5     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 6     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 7     I wanted to set Chicago ablaze with my preachi...       0
# ...                                                 ...     ...
# 3960  #breaking #LA Refugio oil spill may have been ...       1
# 3962  #WorldNews Fallen powerlines on G:link tram: U...       1
# 3963  Suicide bomber kills 15 in Saudi security site...       1
# 3965  Two giant cranes holding a bridge collapse int...       1
# 3966  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
#
#                         link  link_shorted  \
# 1     http://t.co/YAo1e0xngw          True
# 3     http://t.co/qqsmshaJ3N          True
# 5     http://t.co/wDUEaj8Q4J          True
# 6     http://t.co/rOI2NSmEJJ          True
# 7     http://t.co/o9qknbfOFX          True
# ...                      ...           ...
# 3960  http://t.co/5ueCmcv2Pk          True
# 3962  http://t.co/EYSVvzA7Qm          True
# 3963  http://t.co/nF4IculOje          True
# 3965  http://t.co/STfMbbZFB5          True
# 3966  http://t.co/zDtoyd8EbJ          True
#
#                                               real_link error  \
# 1     https://twitter.com/Valis_Ablaze/status/629274...   NaN
# 3     https://twitter.com/AnyOtherAnnaK/status/62919...   NaN
# 5           https://www.youtube.com/watch?v=yG08hLEWzyM   NaN
# 6     https://www.freewebcamsex.me/2015-02-02-taking...   NaN
# 7     https://twitter.com/RevDominic/status/62927230...   NaN
# ...                                                 ...   ...
# 3960  https://www.latimes.com/local/lanow/la-me-ln-r...   NaN
# 3962      https://www.youtube.com/watch?v=yG08hLEWzyM&3   NaN
# 3963  https://www.reuters.com/article/us-saudi-secur...   NaN
# 3965  https://gizmodo.com/two-giant-cranes-holding-a...   NaN
# 3966  https://earthquake.usgs.gov/earthquakes/eventp...   NaN
#
#                                                    page           error_code  \
# 1     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 3     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 5     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 6     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 7     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# ...                                                 ...                  ...
# 3960  b'<!DOCTYPE html>\n<html class="ArticlePage" l...                  nan
# 3962  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3963  b'<!--[if !IE]> This has been served from cach...                  nan
# 3965  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
# 3966  b'<!doctype html>\n<html lang="en">\n\n<head>\...                  nan
#
#                       site  for_graphics
# 1              twitter.com             1
# 3              twitter.com             1
# 5          www.youtube.com             1
# 6     www.freewebcamsex.me             1
# 7              twitter.com             1
# ...                    ...           ...
# 3960       www.latimes.com             1
# 3962       www.youtube.com             1
# 3963       www.reuters.com             1
# 3965           gizmodo.com             1
# 3966   earthquake.usgs.gov             1
#
# [2210 rows x 13 columns]

# %%
def get_the_header(page):
    soup = BeautifulSoup(page, "lxml")
    header = str(soup.h1.string) if soup.h1 else ''
    soup.decompose()
    return header

# %% [raw]
# twt_data_without_error['header'] = twt_data_without_error['page'].map(get_the_header)
# twt_data_without_error

# %% [raw]
# twt_data_without_error.to_csv('../../../DataSets/twt_with_header.csv')

# %%
twt_data_without_error = pd.read_csv('../../../DataSets/twt_with_header.csv').drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
twt_data_without_error
# Out:
#          id keyword                       location  \
# 0        49  ablaze  Est. September 2012 - Bristol
# 1        53  ablaze                     London, UK
# 2        56  ablaze                            NaN
# 3        59  ablaze                 Live On Webcam
# 4        64  ablaze                            NaN
# ...     ...     ...                            ...
# 2205  10859     NaN                            NaN
# 2206  10863     NaN                            NaN
# 2207  10866     NaN                            NaN
# 2208  10869     NaN                            NaN
# 2209  10871     NaN                            NaN
#
#                                                    text  target  \
# 0     We always try to bring the heavy. #metal #RT h...       0
# 1     On plus side LOOK AT THE SKY LAST NIGHT IT WAS...       0
# 2     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 3     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 4     I wanted to set Chicago ablaze with my preachi...       0
# ...                                                 ...     ...
# 2205  #breaking #LA Refugio oil spill may have been ...       1
# 2206  #WorldNews Fallen powerlines on G:link tram: U...       1
# 2207  Suicide bomber kills 15 in Saudi security site...       1
# 2208  Two giant cranes holding a bridge collapse int...       1
# 2209  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
#
#                         link  link_shorted  \
# 0     http://t.co/YAo1e0xngw          True
# 1     http://t.co/qqsmshaJ3N          True
# 2     http://t.co/wDUEaj8Q4J          True
# 3     http://t.co/rOI2NSmEJJ          True
# 4     http://t.co/o9qknbfOFX          True
# ...                      ...           ...
# 2205  http://t.co/5ueCmcv2Pk          True
# 2206  http://t.co/EYSVvzA7Qm          True
# 2207  http://t.co/nF4IculOje          True
# 2208  http://t.co/STfMbbZFB5          True
# 2209  http://t.co/zDtoyd8EbJ          True
#
#                                               real_link                error  \
# 0     https://twitter.com/Valis_Ablaze/status/629274...                  nan
# 1     https://twitter.com/AnyOtherAnnaK/status/62919...                  nan
# 2           https://www.youtube.com/watch?v=yG08hLEWzyM                  nan
# 3     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 4     https://twitter.com/RevDominic/status/62927230...                  nan
# ...                                                 ...                  ...
# 2205  https://www.latimes.com/local/lanow/la-me-ln-r...                  nan
# 2206      https://www.youtube.com/watch?v=yG08hLEWzyM&3                  nan
# 2207  https://www.reuters.com/article/us-saudi-secur...                  nan
# 2208  https://gizmodo.com/two-giant-cranes-holding-a...                  nan
# 2209  https://earthquake.usgs.gov/earthquakes/eventp...                  nan
#
#                                                    page           error_code  \
# 0     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 1     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# 2     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 4     b'<!DOCTYPE html>\n<html lang="es" data-scribe...                  nan
# ...                                                 ...                  ...
# 2205  b'<!DOCTYPE html>\n<html class="ArticlePage" l...                  nan
# 2206  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 2207  b'<!--[if !IE]> This has been served from cach...                  nan
# 2208  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
# 2209  b'<!doctype html>\n<html lang="en">\n\n<head>\...                  nan
#
#                                                  header
# 0                                                  None
# 1                                                  None
# 2     \n              This video is unavailable.\n\n...
# 3     Real Webcam Babes Performing in Hot Live Cam S...
# 4                                                  None
# ...                                                 ...
# 2205  \n        Refugio oil spill may have been cost...
# 2206  \n              This video is unavailable.\n\n...
# 2207  Suicide bomber kills 15 in Saudi security site...
# 2208  Two giant cranes holding a bridge collapse int...
# 2209                                                NaN
#
# [2210 rows x 12 columns]

# %%
twt_data_without_error.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2210 entries, 0 to 2209
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            2210 non-null   int64
#  1   keyword       2198 non-null   object
#  2   location      1598 non-null   object
#  3   text          2210 non-null   object
#  4   target        2210 non-null   int64
#  5   link          2210 non-null   object
#  6   link_shorted  2210 non-null   bool
#  7   real_link     2210 non-null   object
#  8   error         0 non-null      float64
#  9   page          2210 non-null   object
#  10  error_code    0 non-null      float64
#  11  header        1789 non-null   object
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 131.7+ KB

# %% [markdown]
# ## A continuacion nos quedaremos exclusivamente paguinas que nos devolvieron un header para analizar el mismo

# %%
twt_data_without_error = twt_data_without_error.loc[twt_data_without_error["header"] != 'None']
twt_data_without_error = twt_data_without_error.loc[twt_data_without_error["header"] != '']
twt_data_without_error = twt_data_without_error.loc[twt_data_without_error["header"] == twt_data_without_error["header"]]
twt_data_without_error
# Out:
#          id keyword                   location  \
# 2        56  ablaze                        NaN
# 3        59  ablaze             Live On Webcam
# 6        66  ablaze  GREENSBORO,NORTH CAROLINA
# 7        68  ablaze             Live On Webcam
# 8        73  ablaze   Sheffield Township, Ohio
# ...     ...     ...                        ...
# 2201  10844     NaN                        NaN
# 2205  10859     NaN                        NaN
# 2206  10863     NaN                        NaN
# 2207  10866     NaN                        NaN
# 2208  10869     NaN                        NaN
#
#                                                    text  target  \
# 2     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 3     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 6     How the West was burned: Thousands of wildfire...       1
# 7     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 8     Deputies: Man shot before Brighton home set ab...       1
# ...                                                 ...     ...
# 2201  SEVERE WEATHER BULLETIN No. 5 FOR: TYPHOON ÛÏ...       1
# 2205  #breaking #LA Refugio oil spill may have been ...       1
# 2206  #WorldNews Fallen powerlines on G:link tram: U...       1
# 2207  Suicide bomber kills 15 in Saudi security site...       1
# 2208  Two giant cranes holding a bridge collapse int...       1
#
#                         link  link_shorted  \
# 2     http://t.co/wDUEaj8Q4J          True
# 3     http://t.co/rOI2NSmEJJ          True
# 6     http://t.co/vl5TBR3wbr          True
# 7     http://t.co/rOI2NSmEJJ          True
# 8     http://t.co/gWNRhMSO8k          True
# ...                      ...           ...
# 2201  http://t.co/tHhjJw51PE          True
# 2205  http://t.co/5ueCmcv2Pk          True
# 2206  http://t.co/EYSVvzA7Qm          True
# 2207  http://t.co/nF4IculOje          True
# 2208  http://t.co/STfMbbZFB5          True
#
#                                               real_link                error  \
# 2           https://www.youtube.com/watch?v=yG08hLEWzyM                  nan
# 3     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 6     https://mashable.com/2015/08/04/how-the-west-w...                  nan
# 7     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 8     https://chroniclet.com/?utm_source=twitterfeed...                  nan
# ...                                                 ...                  ...
# 2201  https://www.facebook.com/PAGASA.DOST.GOV.PH/po...                  nan
# 2205  https://www.latimes.com/local/lanow/la-me-ln-r...                  nan
# 2206      https://www.youtube.com/watch?v=yG08hLEWzyM&3                  nan
# 2207  https://www.reuters.com/article/us-saudi-secur...                  nan
# 2208  https://gizmodo.com/two-giant-cranes-holding-a...                  nan
#
#                                                    page           error_code  \
# 2     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 6     b'<!DOCTYPE html>\n<html data-env=\'production...                  nan
# 7     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 8     b'\r\n\r\n<!DOCTYPE html>\r\n<html id="ctl00_m...                  nan
# ...                                                 ...                  ...
# 2201  b'<!DOCTYPE html>\n<html lang="en" id="faceboo...                  nan
# 2205  b'<!DOCTYPE html>\n<html class="ArticlePage" l...                  nan
# 2206  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 2207  b'<!--[if !IE]> This has been served from cach...                  nan
# 2208  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
#
#                                                  header
# 2        \n              this video is unavailable.\n\n
# 3     real webcam babes performing in hot live cam s...
# 6     how the west was burned: thousands of wildfire...
# 7     real webcam babes performing in hot live cam s...
# 8     \r\n      elyria and lorain county newspaper |...
# ...                                                 ...
# 2201                                           facebook
# 2205  \n        refugio oil spill may have been cost...
# 2206     \n              this video is unavailable.\n\n
# 2207  suicide bomber kills 15 in saudi security site...
# 2208  two giant cranes holding a bridge collapse int...
#
# [1273 rows x 12 columns]

# %%
#repeticion_de_palabras
twt_data_without_error["header"] = twt_data_without_error["header"].str.lower().str.strip() #transformo todas las palabras a minuscula
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda x: re.sub(r'[^\w]', ' ', x)) #quito todos los caracteres no alfanumericos
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda x: re.sub(r'_', ' ', x))
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda x: re.sub(r'[0-9]',' ', x)) #quito los caracteres numericos
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda s: re.sub(r'\b\w{1}\b', '', s)) #quito las letras sueltas
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda x: re.sub(' +',' ', x)) #quito los espacios de mas
twt_data_without_error["header"] = twt_data_without_error["header"].apply(lambda s: re.sub(r'\b\w{1,2}\b', '', s)) #quito las palabras cortas
twt_data_without_error
# Out:
#          id keyword                   location  \
# 2        56  ablaze                        NaN
# 3        59  ablaze             Live On Webcam
# 6        66  ablaze  GREENSBORO,NORTH CAROLINA
# 7        68  ablaze             Live On Webcam
# 8        73  ablaze   Sheffield Township, Ohio
# ...     ...     ...                        ...
# 2201  10844     NaN                        NaN
# 2205  10859     NaN                        NaN
# 2206  10863     NaN                        NaN
# 2207  10866     NaN                        NaN
# 2208  10869     NaN                        NaN
#
#                                                    text  target  \
# 2     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 3     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 6     How the West was burned: Thousands of wildfire...       1
# 7     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 8     Deputies: Man shot before Brighton home set ab...       1
# ...                                                 ...     ...
# 2201  SEVERE WEATHER BULLETIN No. 5 FOR: TYPHOON ÛÏ...       1
# 2205  #breaking #LA Refugio oil spill may have been ...       1
# 2206  #WorldNews Fallen powerlines on G:link tram: U...       1
# 2207  Suicide bomber kills 15 in Saudi security site...       1
# 2208  Two giant cranes holding a bridge collapse int...       1
#
#                         link  link_shorted  \
# 2     http://t.co/wDUEaj8Q4J          True
# 3     http://t.co/rOI2NSmEJJ          True
# 6     http://t.co/vl5TBR3wbr          True
# 7     http://t.co/rOI2NSmEJJ          True
# 8     http://t.co/gWNRhMSO8k          True
# ...                      ...           ...
# 2201  http://t.co/tHhjJw51PE          True
# 2205  http://t.co/5ueCmcv2Pk          True
# 2206  http://t.co/EYSVvzA7Qm          True
# 2207  http://t.co/nF4IculOje          True
# 2208  http://t.co/STfMbbZFB5          True
#
#                                               real_link                error  \
# 2           https://www.youtube.com/watch?v=yG08hLEWzyM                  nan
# 3     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 6     https://mashable.com/2015/08/04/how-the-west-w...                  nan
# 7     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 8     https://chroniclet.com/?utm_source=twitterfeed...                  nan
# ...                                                 ...                  ...
# 2201  https://www.facebook.com/PAGASA.DOST.GOV.PH/po...                  nan
# 2205  https://www.latimes.com/local/lanow/la-me-ln-r...                  nan
# 2206      https://www.youtube.com/watch?v=yG08hLEWzyM&3                  nan
# 2207  https://www.reuters.com/article/us-saudi-secur...                  nan
# 2208  https://gizmodo.com/two-giant-cranes-holding-a...                  nan
#
#                                                    page           error_code  \
# 2     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 6     b'<!DOCTYPE html>\n<html data-env=\'production...                  nan
# 7     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 8     b'\r\n\r\n<!DOCTYPE html>\r\n<html id="ctl00_m...                  nan
# ...                                                 ...                  ...
# 2201  b'<!DOCTYPE html>\n<html lang="en" id="faceboo...                  nan
# 2205  b'<!DOCTYPE html>\n<html class="ArticlePage" l...                  nan
# 2206  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 2207  b'<!--[if !IE]> This has been served from cach...                  nan
# 2208  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
#
#                                                  header
# 2                                this video unavailable
# 3       real webcam babes performing hot live cam shows
# 6     how the west was burned thousands wildfires ab...
# 7       real webcam babes performing hot live cam shows
# 8              elyria and lorain county newspaper title
# ...                                                 ...
# 2201                                           facebook
# 2205  refugio oil spill may have been costlier bigge...
# 2206                             this video unavailable
# 2207    suicide bomber kills saudi security site mosque
# 2208  two giant cranes holding bridge collapse into ...
#
# [1273 rows x 12 columns]

# %%
twt_data_without_error['header_splited'] = twt_data_without_error['header'].str.split(' ')
twt_data_without_error
# Out:
#          id keyword                   location  \
# 2        56  ablaze                        NaN
# 3        59  ablaze             Live On Webcam
# 6        66  ablaze  GREENSBORO,NORTH CAROLINA
# 7        68  ablaze             Live On Webcam
# 8        73  ablaze   Sheffield Township, Ohio
# ...     ...     ...                        ...
# 2201  10844     NaN                        NaN
# 2205  10859     NaN                        NaN
# 2206  10863     NaN                        NaN
# 2207  10866     NaN                        NaN
# 2208  10869     NaN                        NaN
#
#                                                    text  target  \
# 2     Barbados #Bridgetown JAMAICA ÛÒ Two cars set ...       1
# 3     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 6     How the West was burned: Thousands of wildfire...       1
# 7     Check these out: http://t.co/rOI2NSmEJJ http:/...       0
# 8     Deputies: Man shot before Brighton home set ab...       1
# ...                                                 ...     ...
# 2201  SEVERE WEATHER BULLETIN No. 5 FOR: TYPHOON ÛÏ...       1
# 2205  #breaking #LA Refugio oil spill may have been ...       1
# 2206  #WorldNews Fallen powerlines on G:link tram: U...       1
# 2207  Suicide bomber kills 15 in Saudi security site...       1
# 2208  Two giant cranes holding a bridge collapse int...       1
#
#                         link  link_shorted  \
# 2     http://t.co/wDUEaj8Q4J          True
# 3     http://t.co/rOI2NSmEJJ          True
# 6     http://t.co/vl5TBR3wbr          True
# 7     http://t.co/rOI2NSmEJJ          True
# 8     http://t.co/gWNRhMSO8k          True
# ...                      ...           ...
# 2201  http://t.co/tHhjJw51PE          True
# 2205  http://t.co/5ueCmcv2Pk          True
# 2206  http://t.co/EYSVvzA7Qm          True
# 2207  http://t.co/nF4IculOje          True
# 2208  http://t.co/STfMbbZFB5          True
#
#                                               real_link                error  \
# 2           https://www.youtube.com/watch?v=yG08hLEWzyM                  nan
# 3     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 6     https://mashable.com/2015/08/04/how-the-west-w...                  nan
# 7     https://www.freewebcamsex.me/2015-02-02-taking...                  nan
# 8     https://chroniclet.com/?utm_source=twitterfeed...                  nan
# ...                                                 ...                  ...
# 2201  https://www.facebook.com/PAGASA.DOST.GOV.PH/po...                  nan
# 2205  https://www.latimes.com/local/lanow/la-me-ln-r...                  nan
# 2206      https://www.youtube.com/watch?v=yG08hLEWzyM&3                  nan
# 2207  https://www.reuters.com/article/us-saudi-secur...                  nan
# 2208  https://gizmodo.com/two-giant-cranes-holding-a...                  nan
#
#                                                    page           error_code  \
# 2     b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 3     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 6     b'<!DOCTYPE html>\n<html data-env=\'production...                  nan
# 7     b'\r\n<!DOCTYPE html><html><head><title>Hot Ch...                  nan
# 8     b'\r\n\r\n<!DOCTYPE html>\r\n<html id="ctl00_m...                  nan
# ...                                                 ...                  ...
# 2201  b'<!DOCTYPE html>\n<html lang="en" id="faceboo...                  nan
# 2205  b'<!DOCTYPE html>\n<html class="ArticlePage" l...                  nan
# 2206  b'<!DOCTYPE html><html lang="en" data-cast-api...                  nan
# 2207  b'<!--[if !IE]> This has been served from cach...                  nan
# 2208  b'<!DOCTYPE html><html lang="en-us" data-react...                  nan
#
#                                                  header  \
# 2                                this video unavailable
# 3       real webcam babes performing hot live cam shows
# 6     how the west was burned thousands wildfires ab...
# 7       real webcam babes performing hot live cam shows
# 8              elyria and lorain county newspaper title
# ...                                                 ...
# 2201                                           facebook
# 2205  refugio oil spill may have been costlier bigge...
# 2206                             this video unavailable
# 2207    suicide bomber kills saudi security site mosque
# 2208  two giant cranes holding bridge collapse into ...
#
#                                          header_splited
# 2                            [this, video, unavailable]
# 3     [real, webcam, babes, performing, hot, live, c...
# 6     [how, the, west, was, burned, thousands, wildf...
# 7     [real, webcam, babes, performing, hot, live, c...
# 8       [elyria, and, lorain, county, newspaper, title]
# ...                                                 ...
# 2201                                         [facebook]
# 2205  [refugio, oil, spill, may, have, been, costlie...
# 2206                         [this, video, unavailable]
# 2207  [suicide, bomber, kills, saudi, security, site...
# 2208  [two, giant, cranes, holding, bridge, collapse...
#
# [1273 rows x 13 columns]

# %%
list_stopwords = ["the","and","you","for","that","with","this","from","are","have","was","like","but","just","not","your",\
                 "all","after","will","can","has","when","they","get","new","now","what","amp","","http","https","out",\
                 "more","about","how","there","don","over","into","than","would","been","her","who","were","some","still",\
                 "his","back","why","them","got","know","had","see","going","our","htt","via","nws","wait",\
                 "hwy","top","both","hah","haha","getting","far","near", "video", "unavailable", "cuenta", "suspendida"]
def count_words(word, count):
    if(word in list_stopwords):
        return
    if (word in count):
        count[word] = count[word] + 1
        return
    count[word] = 1

# %%
total_word_count = {}
twt_data_without_error['header_splited'].map(
    lambda x: [count_words(word, total_word_count) for word in x]
)
total_word_count
# Out:
# {'real': 6,
#  'webcam': 2,
#  'babes': 2,
#  'performing': 2,
#  'hot': 4,
#  'live': 5,
#  'cam': 2,
#  'shows': 4,
#  'west': 7,
#  'burned': 4,
#  'thousands': 5,
#  'wildfires': 5,
#  'ablaze': 2,
#  'california': 36,
#  'alone': 2,
#  'elyria': 1,
#  'lorain': 1,
#  'county': 7,
#  'newspaper': 1,
#  'title': 3,
#  'facebook': 63,
#  'san': 1,
#  'francisco': 1,
#  'traffic': 5,
#  'report': 2,
#  'personal': 1,
#  'injury': 3,
#  'lawyer': 1,
#  'sleep': 1,
#  'blog': 8,
#  'big': 3,
#  'rig': 1,
#  'overturns': 2,
#  'fort': 2,
#  'worth': 1,
#  'interstate': 1,
#  'columbus': 2,
#  'aashiqui': 1,
#  'actress': 1,
#  'anu': 1,
#  'aggarwal': 1,
#  'fatal': 3,
#  'accident': 2,
#  'icemoon': 7,
#  'aftershock': 8,
#  'these': 3,
#  'five': 4,
#  'minute': 1,
#  'daily': 1,
#  'habits': 1,
#  'seriously': 1,
#  'improve': 1,
#  'life': 6,
#  'protect': 1,
#  'yourself': 1,
#  'profit': 1,
#  'next': 2,
#  'global': 3,
#  'financial': 3,
#  'meltdown': 2,
#  'cindy': 1,
#  'spitzer': 1,
#  'david': 2,
#  'wiedemer': 2,
#  'robert': 1,
#  'hardcover': 1,
#  'reunion': 11,
#  'island': 11,
#  'wing': 11,
#  'debris': 16,
#  'flight': 10,
#  'malaysia': 9,
#  'prime': 7,
#  'minister': 8,
#  'says': 25,
#  'longer': 25,
#  'available': 7,
#  'because': 5,
#  'youtube': 5,
#  'account': 11,
#  'associated': 5,
#  'terminated': 5,
#  'shropshire': 1,
#  'star': 3,
#  'twelve': 1,
#  'feared': 5,
#  'killed': 2,
#  'pakistani': 2,
#  'air': 2,
#  'ambulance': 1,
#  'helicopter': 4,
#  'crash': 10,
#  'emts': 1,
#  'petition': 6,
#  'per': 1,
#  'hour': 1,
#  'minimum': 1,
#  'wage': 1,
#  'game': 4,
#  'cheats': 2,
#  'tools': 3,
#  'generators': 2,
#  'online': 3,
#  'important': 6,
#  'content': 17,
#  'warning': 9,
#  'armageddon': 2,
#  'payamps': 1,
#  'secret': 2,
#  'penis': 1,
#  'time': 5,
#  'infantry': 1,
#  'mens': 1,
#  'youth': 2,
#  'military': 3,
#  'army': 7,
#  'sport': 3,
#  'quartz': 1,
#  'analog': 1,
#  'wrist': 1,
#  'watch': 4,
#  'blue': 5,
#  'nylon': 1,
#  'strap': 1,
#  'blu': 1,
#  'mourning': 5,
#  'notices': 5,
#  'stabbing': 5,
#  'arson': 12,
#  'victims': 6,
#  'stir': 5,
#  'politics': 6,
#  'grief': 5,
#  'israel': 6,
#  'suspect': 9,
#  'linked': 8,
#  'fires': 10,
#  'caught': 6,
#  'northern': 10,
#  'tennessee': 1,
#  'lesbian': 1,
#  'couple': 3,
#  'faked': 1,
#  'hate': 3,
#  'crime': 1,
#  'destroyed': 3,
#  'own': 2,
#  'home': 9,
#  'insurance': 9,
#  'claim': 3,
#  'jury': 2,
#  'rules': 10,
#  'snappytv': 4,
#  'features': 4,
#  'twitter': 5,
#  'media': 10,
#  'studio': 4,
#  'trusting': 1,
#  'iran': 4,
#  'stop': 6,
#  'terrorism': 3,
#  'inviting': 1,
#  'arsonist': 1,
#  'join': 1,
#  'fire': 19,
#  'brigade': 1,
#  'martin': 1,
#  'amis': 1,
#  'launches': 1,
#  'fresh': 1,
#  'attack': 14,
#  'muslim': 1,
#  'faith': 1,
#  'saying': 3,
#  'islamic': 1,
#  'states': 1,
#  'less': 1,
#  'evolved': 1,
#  'suicide': 19,
#  'bombers': 1,
#  'magazine': 2,
#  'militants': 3,
#  'police': 22,
#  'post': 5,
#  'udhampur': 3,
#  'spos': 2,
#  'injured': 8,
#  'movie': 1,
#  'theater': 7,
#  'attacker': 1,
#  'may': 27,
#  'planned': 3,
#  'set': 2,
#  'off': 15,
#  'explosion': 5,
#  'musician': 2,
#  'kalle': 2,
#  'mattson': 2,
#  'recreates': 2,
#  'classic': 2,
#  'album': 2,
#  'covers': 2,
#  'clever': 2,
#  'music': 4,
#  'avalanche': 2,
#  'front': 2,
#  'row': 1,
#  'trianglefm': 1,
#  'lone': 1,
#  'pine': 1,
#  'trees': 1,
#  'growing': 1,
#  'across': 3,
#  'country': 2,
#  'remembrance': 1,
#  'battle': 2,
#  'gallipoli': 1,
#  'years': 22,
#  'ago': 1,
#  'fedex': 18,
#  'transport': 18,
#  'bioterror': 18,
#  'germs': 18,
#  'wake': 18,
#  'anthrax': 18,
#  'lab': 19,
#  'mishaps': 18,
#  'cdc': 3,
#  'carry': 1,
#  'extensive': 1,
#  'review': 1,
#  'safety': 1,
#  'pathogen': 1,
#  'handling': 1,
#  'procedures': 1,
#  'website': 1,
#  'access': 1,
#  'code': 8,
#  'government': 1,
#  'experts': 3,
#  'concerned': 2,
#  'possible': 4,
#  'bioterrorism': 1,
#  'using': 1,
#  'organisms': 1,
#  'threat': 2,
#  'tauthorities': 1,
#  'allay': 1,
#  'glanders': 1,
#  'fears': 2,
#  'ahead': 2,
#  'rio': 1,
#  'olympic': 1,
#  'equestrian': 1,
#  'test': 1,
#  'event': 5,
#  'nproperty': 1,
#  'losses': 3,
#  'wildfire': 11,
#  'nearly': 4,
#  'double': 3,
#  'week': 1,
#  'old': 10,
#  'blaze': 5,
#  'rages': 2,
#  'firefighters': 3,
#  'east': 3,
#  'cary': 1,
#  'condo': 1,
#  'building': 2,
#  'nchicago': 1,
#  'detained': 1,
#  'black': 2,
#  'americans': 2,
#  'interrogation': 1,
#  'facility': 1,
#  'funny': 2,
#  'videos': 2,
#  'grow': 2,
#  'share': 2,
#  'engage': 2,
#  'prysmian': 1,
#  'secures': 1,
#  'contract': 2,
#  'blight': 3,
#  'bank': 4,
#  'wind': 1,
#  'farm': 1,
#  'cleveland': 1,
#  'heights': 2,
#  'shaker': 1,
#  'fight': 5,
#  'house': 4,
#  'door': 1,
#  'coronavirus': 1,
#  'ohio': 1,
#  'revising': 1,
#  'detroit': 1,
#  'count': 1,
#  'dio': 1,
#  'beats': 1,
#  'nightmare': 1,
#  'elm': 1,
#  'street': 3,
#  'remade': 1,
#  'again': 5,
#  'sony': 1,
#  'sets': 1,
#  'date': 1,
#  'stephen': 1,
#  'king': 2,
#  'dark': 1,
#  'tower': 1,
#  'ronda': 1,
#  'rousey': 1,
#  'close': 1,
#  'making': 2,
#  'floyd': 1,
#  'mayweather': 1,
#  'money': 2,
#  'fights': 1,
#  'came': 1,
#  'kill': 5,
#  'indians': 1,
#  'fun': 1,
#  'smirking': 1,
#  'remorseless': 1,
#  'killer': 3,
#  'shot': 1,
#  'two': 20,
#  'servicemen': 1,
#  'him': 1,
#  'boasting': 1,
#  'bloody': 2,
#  'murders': 1,
#  'connect': 1,
#  'zimbabwe': 1,
#  'cry': 1,
#  'lions': 1,
#  'todd': 1,
#  'blake': 1,
#  'helps': 1,
#  'fellow': 1,
#  'young': 3,
#  'adult': 2,
#  'cancer': 4,
#  'patients': 1,
#  'find': 6,
#  'adventure': 1,
#  'through': 1,
#  'changing': 1,
#  'experiences': 1,
#  'learn': 2,
#  'truly': 1,
#  'means': 1,
#  'accelereader': 1,
#  'power': 5,
#  'pocket': 2,
#  'experience': 1,
#  'bolsos': 8,
#  'carteras': 8,
#  'para': 8,
#  'mujer': 8,
#  'institute': 1,
#  'peace': 2,
#  'chairman': 1,
#  'wants': 2,
#  'russian': 11,
#  'body': 5,
#  'bags': 3,
#  'fairfax': 2,
#  'firefighter': 5,
#  'placed': 1,
#  'administrative': 1,
#  'leave': 1,
#  'inciting': 1,
#  'violence': 4,
#  'against': 8,
#  'investigating': 3,
#  'should': 2,
#  'put': 1,
#  'nhiroshima': 3,
#  'remembers': 2,
#  'day': 9,
#  'bomb': 20,
#  'dropped': 2,
#  'documents': 2,
#  'found': 6,
#  'pointing': 2,
#  'japan': 16,
#  'wwii': 2,
#  'atomic': 26,
#  'program': 2,
#  'hiroshima': 28,
#  'marks': 4,
#  'since': 2,
#  'lost': 2,
#  'sea': 2,
#  'okinawa': 1,
#  'admits': 1,
#  'nthe': 1,
#  'great': 2,
#  'identity': 1,
#  'crisis': 14,
#  'turkish': 4,
#  'jets': 1,
#  'bombed': 1,
#  'villages': 1,
#  'redskins': 1,
#  'chris': 2,
#  'baker': 1,
#  'interrupts': 1,
#  'andre': 1,
#  'roberts': 1,
#  'interview': 1,
#  'belly': 1,
#  'dance': 1,
#  'mario': 1,
#  'travels': 1,
#  'truth': 1,
#  'bombing': 10,
#  'anniversary': 4,
#  'moment': 2,
#  'silence': 1,
#  'bells': 1,
#  'toll': 3,
#  'human': 2,
#  'cost': 2,
#  'historical': 2,
#  'narrative': 2,
#  'swiss': 1,
#  'kosher': 1,
#  'hotel': 1,
#  'bridge': 8,
#  'collapse': 16,
#  'injures': 2,
#  'people': 12,
#  'warne': 2,
#  'shocked': 2,
#  'australia': 6,
#  'epic': 6,
#  'trent': 2,
#  'giant': 7,
#  'cranes': 6,
#  'holding': 5,
#  'nearby': 5,
#  'homes': 12,
#  'soma': 3,
#  'search': 6,
#  'location': 5,
#  'zip': 5,
#  'multiple': 1,
#  'buildings': 3,
#  'downtown': 4,
#  'hinton': 1,
#  'change': 6,
#  'prohibits': 1,
#  'grills': 1,
#  'decks': 1,
#  'residents': 3,
#  'apartments': 3,
#  'condos': 1,
#  'three': 5,
#  'alarm': 7,
#  'destroys': 1,
#  'acres': 2,
#  'camp': 3,
#  'pendleton': 1,
#  'mocks': 1,
#  'harper': 1,
#  'appearance': 1,
#  'metal': 2,
#  'cutting': 1,
#  'sparks': 2,
#  'brush': 1,
#  'brighton': 1,
#  'best': 1,
#  'testosterone': 1,
#  'booster': 1,
#  'results': 1,
#  'revealed': 4,
#  'kanger': 1,
#  'coils': 1,
#  'burning': 3,
#  'fast': 1,
#  'parents': 4,
#  'taking': 3,
#  'their': 3,
#  'kids': 3,
#  'man': 7,
#  'one': 3,
#  'year': 4,
#  'thinks': 1,
#  'better': 1,
#  'disney': 1,
#  'world': 5,
#  'creaxion': 1,
#  'lanza': 1,
#  'form': 1,
#  'marketing': 1,
#  'alliance': 1,
#  'port': 1,
#  'coquitlam': 1,
#  'core': 1,
#  'reopens': 1,
#  'collapses': 1,
#  'four': 4,
#  'grows': 4,
#  'closes': 2,
#  'highways': 1,
#  'error': 3,
#  'summer': 8,
#  'herald': 1,
#  'mountains': 1,
#  'bush': 1,
#  'torch': 1,
#  'counting': 1,
#  'dear': 1,
#  'friend': 3,
#  'american': 2,
#  'weapons': 3,
#  'support': 1,
#  'fueling': 1,
#  'war': 4,
#  'yemen': 1,
#  'news': 50,
#  'wrap': 1,
#  'warns': 2,
#  'female': 1,
#  'child': 1,
#  'casualties': 2,
#  'rise': 4,
#  'afghanistan': 1,
#  'nafghanistan': 1,
#  'sharp': 2,
#  'women': 4,
#  'children': 6,
#  'first': 13,
#  'half': 1,
#  'break': 1,
#  'room': 2,
#  'covid': 1,
#  'information': 4,
#  'property': 3,
#  'casualty': 3,
#  'rates': 1,
#  'edge': 1,
#  'july': 3,
#  'status': 2,
#  'article': 2,
#  'detail': 1,
#  'documenting': 1,
#  'climate': 5,
#  'major': 3,
#  'canceling': 2,
#  'deal': 3,
#  'warships': 2,
#  'france': 2,
#  'agrees': 2,
#  'repay': 2,
#  'russia': 5,
#  'borrowers': 1,
#  'interest': 1,
#  'rate': 3,
#  'pixels': 1,
#  'catastrophe': 1,
#  'kanyuu': 1,
#  'catastrophic': 7,
#  'fallen': 1,
#  'angel': 1,
#  'reveillertm': 1,
#  'obama': 1,
#  'takes': 2,
#  'opponents': 1,
#  'learning': 6,
#  'legacy': 6,
#  'eruption': 6,
#  'xbe': 5,
#  'xbd': 10,
#  'xbf': 7,
#  'xbb': 2,
#  'xba': 3,
#  'emergency': 18,
#  'keep': 4,
#  'ban': 5,
#  'bee': 4,
#  'killing': 5,
#  'pesticides': 4,
#  'chemical': 1,
#  'plant': 2,
#  'long': 2,
#  'term': 2,
#  'effects': 1,
#  'creek': 1,
#  'under': 12,
#  'investigation': 1,
#  'photographer': 3,
#  'brian': 3,
#  'ruebs': 3,
#  'endures': 3,
#  'feet': 3,
#  'climb': 3,
#  'capture': 5,
#  'bride': 3,
#  'groom': 3,
#  'programmering': 1,
#  'runaway': 1,
#  'minion': 1,
#  'causes': 2,
#  'dublin': 1,
#  'terrifying': 1,
#  'onto': 1,
#  'survivors': 6,
#  'hampshire': 1,
#  'circus': 1,
#  'tent': 1,
#  'recall': 4,
#  'horror': 1,
#  'confusion': 1,
#  'ngreece': 2,
#  'tax': 4,
#  'revenues': 3,
#  'debt': 3,
#  'continues': 4,
#  'ashes': 3,
#  'batting': 1,
#  'huge': 3,
#  'amount': 1,
#  'trolling': 1,
#  'due': 5,
#  'copyright': 2,
#  'third': 2,
#  'party': 3,
#  'greece': 1,
#  'pomicide': 1,
#  'reacts': 1,
#  'mgn': 1,
#  'africa': 1,
#  'order': 3,
#  'sessions': 1,
#  'germany': 1,
#  'bay': 1,
#  'district': 1,
#  'coaches': 2,
#  'cpr': 1,
#  'during': 17,
#  'medical': 1,
#  'course': 1,
#  'dailynew': 1,
#  'com': 9,
#  'art': 2,
#  'electronics': 1,
#  'collide': 3,
#  'city': 45,
#  'hosts': 1,
#  'mind': 1,
#  'blowing': 1,
#  'symposium': 1,
#  'school': 6,
#  'buses': 1,
#  'cars': 4,
#  'collided': 1,
#  'following': 8,
#  'shotgun': 1,
#  'denton': 1,
#  'crashes': 1,
#  'bicycle': 1,
#  'suv': 1,
#  'mesick': 1,
#  'latest': 4,
#  'motorsport': 1,
#  'friends': 1,
#  'family': 4,
#  'throw': 1,
#  'bestival': 1,
#  'victim': 5,
#  'michael': 1,
#  'molloy': 1,
#  'birthday': 1,
#  'cop': 1,
#  'reaches': 3,
#  'tracks': 5,
#  'train': 15,
#  'nears': 2,
#  'tthief': 1,
#  'broke': 1,
#  'window': 1,
#  'hicksville': 1,
#  'store': 1,
#  'stole': 1,
#  'cell': 1,
#  'phones': 1,
#  'fled': 1,
#  'crashed': 1,
#  'guardrail': 1,
#  'say': 7,
#  'oil': 29,
#  'prices': 1,
#  'crushed': 1,
#  'drivers': 1,
#  'could': 5,
#  'joy': 1,
#  'pump': 3,
#  'bolt': 1,
#  'cyclone': 5,
#  'dual': 1,
#  'outlet': 1,
#  'pack': 1,
#  'bbc': 2,
#  'forced': 3,
#  'retract': 2,
#  'false': 6,
#  'claims': 6,
#  'pam': 2,
#  'tropical': 2,
#  'coroner': 1,
#  'spokesman': 1,
#  'signs': 1,
#  'drugs': 1,
#  'alcohol': 1,
#  'use': 2,
#  'vroman': 1,
#  'death': 10,
#  'wfp': 1,
#  'delivers': 1,
#  'food': 15,
#  'bangladesh': 1,
#  'flood': 5,
#  'komen': 1,
#  'storm': 13,
#  'damage': 6,
#  'reported': 3,
#  'madison': 2,
#  'does': 3,
#  'homeowners': 2,
#  'cover': 2,
#  'fence': 1,
#  'water': 18,
#  'architects': 1,
#  'slam': 1,
#  'queen': 2,
#  'wharf': 1,
#  'casino': 1,
#  'site': 9,
#  'warn': 1,
#  'irreparable': 1,
#  'brisbane': 1,
#  'booming': 1,
#  'license': 1,
#  'sales': 1,
#  'show': 6,
#  'florida': 1,
#  'bear': 1,
#  'hunters': 3,
#  'bears': 1,
#  'reinhard': 1,
#  'bonnke': 1,
#  'tells': 1,
#  'nigerian': 1,
#  'raised': 1,
#  'dead': 10,
#  'dies': 2,
#  'plague': 3,
#  'colorado': 6,
#  'later': 1,
#  'ferguson': 1,
#  'sees': 2,
#  'asks': 1,
#  'slain': 1,
#  'mexican': 1,
#  'journalist': 1,
#  'unknowingly': 1,
#  'predicted': 1,
#  'overall': 1,
#  'cases': 3,
#  'york': 6,
#  'legionnaires': 30,
#  'disease': 30,
#  'outbreak': 30,
#  'rises': 1,
#  'transcript': 1,
#  'telebriefing': 1,
#  'improved': 1,
#  'infection': 1,
#  'control': 1,
#  'many': 4,
#  'antibiotic': 1,
#  'resistant': 1,
#  'related': 3,
#  'infections': 1,
#  'deaths': 8,
#  'predict': 1,
#  'averted': 1,
#  'critters': 2,
#  'fco': 1,
#  'condemns': 1,
#  'mosque': 9,
#  'saudi': 12,
#  'arabia': 1,
#  'walmart': 1,
#  'announces': 3,
#  'infant': 2,
#  'car': 2,
#  'seat': 1,
#  'designed': 1,
#  'prevent': 1,
#  'bigamist': 1,
#  'wife': 2,
#  'charged': 3,
#  'mother': 1,
#  'law': 2,
#  'missing': 11,
#  'plane': 10,
#  'najib': 4,
#  'discovered': 1,
#  'airlines': 4,
#  'jet': 1,
#  'floated': 2,
#  'union': 3,
#  'almost': 2,
#  'surely': 2,
#  'officials': 6,
#  'malaysian': 5,
#  'washed': 5,
#  'indian': 6,
#  'ocean': 6,
#  'french': 5,
#  'investigator': 4,
#  'waiting': 4,
#  'final': 4,
#  'confirmation': 4,
#  'aircraft': 1,
#  'confirmed': 4,
#  'floods': 6,
#  'health': 2,
#  'guide': 42,
#  'china': 3,
#  'only': 2,
#  'delaying': 1,
#  'deluge': 1,
#  'dumuzid': 1,
#  'vince': 1,
#  'mcmahon': 1,
#  'once': 1,
#  'billionaire': 1,
#  'context': 1,
#  'reid': 3,
#  'calais': 1,
#  'migrant': 6,
#  'tunnel': 1,
#  'crypto': 1,
#  'export': 1,
#  'commerce': 1,
#  'department': 3,
#  'withdraws': 1,
#  'proposal': 1,
#  'promises': 1,
#  'rewrite': 1,
#  'clet': 1,
#  'demolish': 3,
#  'laundry': 1,
#  'liberman': 1,
#  'calls': 3,
#  'illegal': 2,
#  'sussiya': 1,
#  'suites': 1,
#  'offices': 1,
#  'coming': 2,
#  'salvi': 1,
#  'bistro': 1,
#  'firm': 1,
#  'irish': 2,
#  'ring': 1,
#  'demolished': 3,
#  'palestinian': 2,
#  'village': 3,
#  'comes': 5,
#  'unrecognized': 1,
#  'arab': 1,
#  'remaining': 1,
#  'sections': 1,
#  'greystone': 1,
#  'psychiatric': 1,
#  'hospital': 2,
#  'demolition': 3,
#  'full': 2,
#  'moon': 1,
#  'azmovielist': 1,
#  'net': 1,
#  'estate': 1,
#  'blackboard': 1,
#  'saved': 2,
#  'opal': 1,
#  'community': 1,
#  'land': 2,
#  'trust': 1,
#  'canberra': 1,
#  'fluffy': 1,
#  'schedule': 2,
#  'released': 7,
#  'here': 7,
#  'caused': 3,
#  'metro': 2,
#  'derail': 6,
#  'heroku': 1,
#  'india': 6,
#  'rail': 3,
#  'trains': 4,
#  'madhya': 7,
#  'pradesh': 7,
#  'flash': 5,
#  'fox': 3,
#  'court': 1,
#  'blocks': 1,
#  'backed': 1,
#  'coal': 1,
#  'mine': 2,
#  'times': 2,
#  'love': 2,
#  'derailed': 1,
#  'staying': 1,
#  'track': 2,
#  'railway': 1,
#  'rains': 2,
#  'cannot': 1,
#  'take': 5,
#  'blame': 1,
#  'derailment': 6,
#  'lives': 1,
#  'twin': 4,
#  'freakiest': 4,
#  'freak': 4,
#  'accidents': 5,
#  'helping': 2,
#  'hand': 2,
#  'mumbai': 2,
#  'ttes': 2,
#  'charge': 2,
#  'helpline': 2,
#  'calm': 6,
#  'anxious': 2,
#  'relatives': 2,
#  'patna': 1,
#  'any': 1,
#  'similar': 2,
#  'authors': 2,
#  'follow': 2,
#  'stream': 1,
#  'events': 1,
#  'genre': 1,
#  'ahello': 1,
#  'tiny': 1,
#  'littlebitofbass': 1,
#  'silinski': 1,
#  'sheeran': 1,
#  'free': 1,
#  'hobbit': 1,
#  'desolation': 2,
#  'smaug': 1,
#  'digital': 1,
#  'download': 1,
#  'gin': 1,
#  'william': 1,
#  'struse': 1,
#  'fighters': 1,
#  'mile': 1,
#  'mountain': 2,
#  'run': 3,
#  'lake': 4,
#  'map': 1,
#  'problematique': 1,
#  'putin': 1,
#  'plan': 10,
#  'destroy': 2,
#  'western': 1,
#  'masse': 1,
#  'causing': 1,
#  'public': 3,
#  'backlash': 1,
#  'fahrenheit': 1,
#  'disambiguation': 1,
#  'super': 4,
#  'strong': 1,
#  'magnets': 1,
#  'everyday': 1,
#  'objects': 1,
#  'stocks': 1,
#  'clobbered': 1,
#  'authorities': 1,
#  'destruction': 6,
#  'sanctioned': 1,
#  'bureaucrats': 1,
#  'singled': 1,
#  'crackdown': 2,
#  'restricted': 2,
#  'multiplayer': 2,
#  'update': 2,
#  'begins': 1,
#  'mass': 1,
#  'illegally': 1,
#  ...}

# %%
disaster_word_count = {}
twt_data_without_error.loc[twt_data_without_error['target'] == 1,'header_splited'].map(
    lambda x: [count_words(word, disaster_word_count) for word in x] if (x != None) else None
)
disaster_word_count
# Out:
# {'west': 6,
#  'burned': 3,
#  'thousands': 4,
#  'wildfires': 5,
#  'ablaze': 2,
#  'california': 34,
#  'alone': 2,
#  'elyria': 1,
#  'lorain': 1,
#  'county': 6,
#  'newspaper': 1,
#  'title': 3,
#  'san': 1,
#  'francisco': 1,
#  'traffic': 5,
#  'report': 2,
#  'facebook': 26,
#  'big': 2,
#  'rig': 1,
#  'overturns': 2,
#  'fort': 1,
#  'worth': 1,
#  'interstate': 1,
#  'columbus': 1,
#  'aashiqui': 1,
#  'actress': 1,
#  'anu': 1,
#  'aggarwal': 1,
#  'fatal': 3,
#  'accident': 2,
#  'reunion': 11,
#  'island': 11,
#  'wing': 11,
#  'debris': 16,
#  'flight': 10,
#  'malaysia': 9,
#  'prime': 7,
#  'minister': 8,
#  'says': 25,
#  'longer': 15,
#  'available': 5,
#  'because': 5,
#  'youtube': 5,
#  'account': 8,
#  'associated': 5,
#  'terminated': 5,
#  'shropshire': 1,
#  'star': 2,
#  'twelve': 1,
#  'feared': 5,
#  'killed': 2,
#  'pakistani': 2,
#  'air': 2,
#  'ambulance': 1,
#  'helicopter': 4,
#  'crash': 9,
#  'game': 3,
#  'cheats': 2,
#  'tools': 2,
#  'generators': 2,
#  'online': 3,
#  'important': 6,
#  'mourning': 4,
#  'notices': 4,
#  'stabbing': 4,
#  'arson': 11,
#  'victims': 5,
#  'stir': 4,
#  'politics': 4,
#  'grief': 4,
#  'israel': 5,
#  'suspect': 9,
#  'linked': 7,
#  'fires': 9,
#  'caught': 6,
#  'northern': 10,
#  'tennessee': 1,
#  'lesbian': 1,
#  'couple': 3,
#  'faked': 1,
#  'hate': 3,
#  'crime': 1,
#  'destroyed': 2,
#  'own': 1,
#  'home': 5,
#  'insurance': 7,
#  'claim': 1,
#  'jury': 2,
#  'rules': 3,
#  'suicide': 19,
#  'bombers': 1,
#  'magazine': 2,
#  'militants': 3,
#  'attack': 13,
#  'police': 14,
#  'post': 2,
#  'udhampur': 3,
#  'spos': 2,
#  'injured': 7,
#  'snappytv': 3,
#  'features': 3,
#  'twitter': 3,
#  'media': 5,
#  'studio': 3,
#  'movie': 1,
#  'theater': 7,
#  'attacker': 1,
#  'may': 24,
#  'planned': 2,
#  'set': 1,
#  'off': 12,
#  'explosion': 5,
#  'trianglefm': 1,
#  'fedex': 10,
#  'transport': 10,
#  'bioterror': 10,
#  'germs': 10,
#  'wake': 10,
#  'anthrax': 10,
#  'lab': 11,
#  'mishaps': 10,
#  'cdc': 1,
#  'carry': 1,
#  'extensive': 1,
#  'review': 1,
#  'safety': 1,
#  'pathogen': 1,
#  'handling': 1,
#  'procedures': 1,
#  'website': 1,
#  'access': 1,
#  'code': 6,
#  'government': 1,
#  'experts': 1,
#  'concerned': 1,
#  'possible': 2,
#  'bioterrorism': 1,
#  'using': 1,
#  'organisms': 1,
#  'threat': 1,
#  'tauthorities': 1,
#  'allay': 1,
#  'glanders': 1,
#  'fears': 2,
#  'ahead': 1,
#  'rio': 1,
#  'olympic': 1,
#  'equestrian': 1,
#  'test': 1,
#  'event': 4,
#  'nproperty': 1,
#  'losses': 3,
#  'wildfire': 9,
#  'nearly': 4,
#  'double': 3,
#  'week': 1,
#  'old': 8,
#  'blaze': 5,
#  'rages': 2,
#  'firefighters': 3,
#  'battle': 1,
#  'east': 3,
#  'cary': 1,
#  'condo': 1,
#  'building': 2,
#  'came': 1,
#  'kill': 4,
#  'indians': 1,
#  'fun': 1,
#  'smirking': 1,
#  'remorseless': 1,
#  'killer': 2,
#  'shot': 1,
#  'two': 18,
#  'servicemen': 1,
#  'shows': 2,
#  'him': 1,
#  'boasting': 1,
#  'bloody': 2,
#  'murders': 1,
#  'zimbabwe': 1,
#  'cry': 1,
#  'lions': 1,
#  'bolsos': 1,
#  'carteras': 1,
#  'para': 1,
#  'mujer': 1,
#  'nhiroshima': 3,
#  'remembers': 2,
#  'day': 4,
#  'bomb': 20,
#  'dropped': 2,
#  'documents': 2,
#  'found': 6,
#  'pointing': 2,
#  'japan': 16,
#  'wwii': 2,
#  'atomic': 26,
#  'program': 2,
#  'hiroshima': 28,
#  'marks': 4,
#  'years': 19,
#  'since': 2,
#  'lost': 2,
#  'sea': 2,
#  'okinawa': 1,
#  'admits': 1,
#  'nthe': 1,
#  'great': 2,
#  'identity': 1,
#  'crisis': 14,
#  'turkish': 3,
#  'jets': 1,
#  'bombed': 1,
#  'these': 2,
#  'villages': 1,
#  'redskins': 1,
#  'chris': 1,
#  'baker': 1,
#  'interrupts': 1,
#  'andre': 1,
#  'roberts': 1,
#  'interview': 1,
#  'belly': 1,
#  'dance': 1,
#  'mario': 1,
#  'travels': 1,
#  'truth': 1,
#  'bombing': 10,
#  'anniversary': 4,
#  'moment': 2,
#  'silence': 1,
#  'bells': 1,
#  'toll': 3,
#  'human': 2,
#  'cost': 2,
#  'historical': 2,
#  'narrative': 2,
#  'swiss': 1,
#  'kosher': 1,
#  'hotel': 1,
#  'bridge': 8,
#  'collapse': 13,
#  'injures': 2,
#  'five': 2,
#  'people': 6,
#  'warne': 2,
#  'shocked': 2,
#  'australia': 2,
#  'epic': 2,
#  'trent': 2,
#  'giant': 7,
#  'cranes': 6,
#  'holding': 5,
#  'nearby': 5,
#  'homes': 11,
#  'search': 6,
#  'location': 5,
#  'zip': 5,
#  'multiple': 1,
#  'buildings': 3,
#  'fire': 16,
#  'downtown': 4,
#  'hinton': 1,
#  'three': 5,
#  'alarm': 6,
#  'destroys': 1,
#  'firefighter': 3,
#  'acres': 2,
#  'camp': 3,
#  'pendleton': 1,
#  'metal': 1,
#  'cutting': 1,
#  'sparks': 1,
#  'brush': 1,
#  'brighton': 1,
#  'best': 1,
#  'testosterone': 1,
#  'booster': 1,
#  'results': 1,
#  'revealed': 2,
#  'port': 1,
#  'coquitlam': 1,
#  'core': 1,
#  'reopens': 1,
#  'collapses': 1,
#  'four': 4,
#  'grows': 4,
#  'closes': 2,
#  'highways': 1,
#  'error': 3,
#  'summer': 3,
#  'herald': 1,
#  'blue': 2,
#  'mountains': 1,
#  'bush': 1,
#  'torch': 1,
#  'counting': 1,
#  'dear': 1,
#  'friend': 1,
#  'american': 2,
#  'weapons': 1,
#  'support': 1,
#  'fueling': 1,
#  'war': 4,
#  'yemen': 1,
#  'news': 22,
#  'wrap': 1,
#  'warns': 2,
#  'female': 1,
#  'child': 1,
#  'casualties': 2,
#  'rise': 3,
#  'afghanistan': 1,
#  'nafghanistan': 1,
#  'sharp': 2,
#  'women': 3,
#  'children': 5,
#  'first': 10,
#  'half': 1,
#  'break': 1,
#  'room': 2,
#  'property': 3,
#  'casualty': 3,
#  'rates': 1,
#  'edge': 1,
#  'july': 1,
#  'article': 2,
#  'detail': 1,
#  'documenting': 1,
#  'climate': 5,
#  'change': 3,
#  'major': 3,
#  'obama': 1,
#  'takes': 1,
#  'opponents': 1,
#  'iran': 3,
#  'deal': 1,
#  'learning': 6,
#  'legacy': 6,
#  'catastrophic': 6,
#  'eruption': 6,
#  'xbe': 4,
#  'xbd': 4,
#  'xbf': 3,
#  'xbb': 2,
#  'xba': 1,
#  'runaway': 1,
#  'minion': 1,
#  'causes': 2,
#  'dublin': 1,
#  'watch': 3,
#  'terrifying': 1,
#  'onto': 1,
#  'ngreece': 2,
#  'tax': 4,
#  'revenues': 3,
#  'debt': 3,
#  'continues': 3,
#  'greece': 1,
#  'bay': 1,
#  'district': 1,
#  'coaches': 2,
#  'learn': 1,
#  'cpr': 1,
#  'during': 14,
#  'medical': 1,
#  'course': 1,
#  'dailynew': 1,
#  'com': 5,
#  'school': 5,
#  'buses': 1,
#  'collide': 2,
#  'cars': 3,
#  'collided': 1,
#  'following': 8,
#  'shotgun': 1,
#  'denton': 1,
#  'crashes': 1,
#  'bicycle': 1,
#  'suv': 1,
#  'mesick': 1,
#  'friends': 1,
#  'family': 3,
#  'throw': 1,
#  'party': 1,
#  'bestival': 1,
#  'victim': 5,
#  'michael': 1,
#  'molloy': 1,
#  'birthday': 1,
#  'cop': 1,
#  'reaches': 3,
#  'man': 5,
#  'tracks': 5,
#  'train': 15,
#  'nears': 2,
#  'bbc': 2,
#  'forced': 3,
#  'retract': 2,
#  'false': 6,
#  'claims': 6,
#  'cyclone': 4,
#  'pam': 2,
#  'tropical': 2,
#  'information': 2,
#  'wfp': 1,
#  'delivers': 1,
#  'food': 11,
#  'bangladesh': 1,
#  'flood': 5,
#  'komen': 1,
#  'storm': 13,
#  'damage': 4,
#  'reported': 3,
#  'madison': 2,
#  'does': 1,
#  'homeowners': 1,
#  'cover': 1,
#  'water': 18,
#  'adult': 1,
#  'dies': 2,
#  'plague': 3,
#  'colorado': 6,
#  'death': 7,
#  'overall': 1,
#  'cases': 3,
#  'york': 4,
#  'legionnaires': 30,
#  'disease': 30,
#  'outbreak': 30,
#  'rises': 1,
#  'critters': 2,
#  'deaths': 6,
#  'fco': 1,
#  'condemns': 1,
#  'mosque': 9,
#  'saudi': 12,
#  'arabia': 1,
#  'bigamist': 1,
#  'wife': 2,
#  'charged': 3,
#  'mother': 1,
#  'law': 2,
#  'missing': 11,
#  'plane': 10,
#  'najib': 4,
#  'discovered': 1,
#  'airlines': 3,
#  'jet': 1,
#  'could': 2,
#  'floated': 2,
#  'union': 3,
#  'almost': 2,
#  'surely': 2,
#  'officials': 6,
#  'say': 5,
#  'malaysian': 5,
#  'washed': 5,
#  'indian': 4,
#  'ocean': 6,
#  'french': 4,
#  'investigator': 4,
#  'waiting': 4,
#  'final': 4,
#  'confirmation': 4,
#  'aircraft': 1,
#  'confirmed': 4,
#  'floods': 6,
#  'health': 2,
#  'guide': 16,
#  'context': 1,
#  'king': 1,
#  'calais': 1,
#  'migrant': 6,
#  'one': 1,
#  'dead': 9,
#  'tunnel': 1,
#  'liberman': 1,
#  'calls': 2,
#  'demolish': 1,
#  'illegal': 2,
#  'sussiya': 1,
#  'demolished': 3,
#  'palestinian': 2,
#  'village': 3,
#  'comes': 1,
#  'life': 3,
#  'unrecognized': 1,
#  'arab': 1,
#  'azmovielist': 1,
#  'net': 1,
#  'real': 2,
#  'estate': 1,
#  'blackboard': 1,
#  'here': 4,
#  'caused': 3,
#  'metro': 2,
#  'derail': 6,
#  'india': 5,
#  'rail': 3,
#  'trains': 4,
#  'madhya': 7,
#  'pradesh': 7,
#  'flash': 5,
#  'killing': 1,
#  'fox': 1,
#  'railway': 1,
#  'track': 1,
#  'rains': 2,
#  'cannot': 1,
#  'take': 3,
#  'blame': 1,
#  'derailment': 6,
#  'youth': 1,
#  'saved': 1,
#  'many': 2,
#  'lives': 1,
#  'twin': 4,
#  'freakiest': 4,
#  'freak': 4,
#  'accidents': 5,
#  'helping': 2,
#  'hand': 2,
#  'mumbai': 2,
#  'ttes': 2,
#  'charge': 2,
#  'helpline': 2,
#  'calm': 6,
#  'anxious': 2,
#  'relatives': 2,
#  'patna': 1,
#  'any': 1,
#  'similar': 1,
#  'authors': 1,
#  'follow': 1,
#  'live': 1,
#  'stream': 1,
#  'events': 1,
#  'genre': 1,
#  'fighters': 1,
#  'super': 1,
#  'strong': 1,
#  'magnets': 1,
#  'destroy': 1,
#  'everyday': 1,
#  'objects': 1,
#  'bureaucrats': 1,
#  'singled': 1,
#  'destruction': 3,
#  'russia': 2,
#  'begins': 1,
#  'mass': 1,
#  'illegally': 1,
#  'imported': 1,
#  'vincente': 1,
#  'montano': 1,
#  'identified': 1,
#  'antioch': 1,
#  'seventy': 1,
#  'nagasaki': 4,
#  'reflections': 1,
#  'consequences': 2,
#  'nuclear': 13,
#  'detonation': 1,
#  'millions': 2,
#  'locusts': 1,
#  'cause': 2,
#  'biblical': 1,
#  'devastation': 2,
#  'southern': 2,
#  'bombs': 12,
#  'struggles': 11,
#  'wartime': 11,
#  'past': 11,
#  'series': 1,
#  'part': 2,
#  'hidden': 1,
#  'decades': 1,
#  'una': 4,
#  'todo': 4,
#  'google': 4,
#  'look': 2,
#  'hit': 4,
#  'city': 19,
#  'blog': 2,
#  'ilo': 1,
#  'illinois': 2,
#  'tornado': 4,
#  'slipped': 2,
#  'under': 4,
#  'radar': 2,
#  'emergency': 4,
#  'stop': 4,
#  'meddling': 3,
#  'north': 3,
#  'queensland': 3,
#  'suncorp': 3,
#  'inside': 2,
#  'sittwe': 2,
#  'point': 3,
#  'return': 4,
#  'burma': 2,
#  'displaced': 4,
#  'rohingya': 2,
#  'flooding': 8,
#  'asia': 1,
#  'displaces': 1,
#  'rising': 2,
#  'rapidly': 1,
#  'families': 26,
#  'mechanicsburg': 1,
#  'elem': 2,
#  'evacuation': 7,
#  'center': 3,
#  'noaa': 4,
#  'predicts': 4,
#  'hurricane': 4,
#  'season': 4,
#  'organized': 1,
#  'make': 2,
#  'plan': 4,
#  'realize': 1,
#  'dreams': 1,
#  'nnema': 1,
#  'nigerians': 1,
#  'prepare': 2,
#  'drought': 8,
#  'rating': 2,
#  'maxed': 1,
#  'gov': 1,
#  'brown': 1,
#  'links': 1,
#  'treasures': 1,
#  'drains': 1,
#  'lakes': 1,
#  'okanagan': 1,
#  'region': 3,
#  'issued': 1,
#  'level': 1,
#  'ttechnology': 1,
#  'down': 4,
#  'nhow': 1,
#  'marijuana': 1,
#  'making': 1,
#  'worse': 1,
#  'makes': 1,
#  'quest': 1,
#  'consuming': 1,
#  'grind': 1,
#  'hundreds': 8,
#  'drowned': 6,
#  'boat': 8,
#  'capsizes': 6,
#  'libya': 6,
#  'migrants': 6,
#  'drown': 1,
#  'toddler': 3,
#  'bath': 1,
#  'literally': 1,
#  'minutes': 1,
#  'mum': 1,
#  'left': 1,
#  'fetch': 1,
#  'pyjamas': 1,
#  'jacksonville': 1,
#  'bands': 1,
#  'together': 1,
#  'memorial': 1,
#  'cookout': 1,
#  'mediterranean': 20,
#  'believed': 1,
#  'board': 2,
#  'xac': 1,
#  'xaa': 3,
#  'xab': 1,
#  'xaf': 4,
#  'xad': 1,
#  'state': 3,
#  'upgrading': 1,
#  'ferry': 1,
#  'docks': 2,
#  'earthquake': 2,
#  'standards': 1,
#  'vashon': 1,
#  'mukilteo': 1,
#  'renison': 1,
#  'mine': 1,
#  'sees': 1,
#  'seismic': 2,
#  'quake': 1,
#  'thu': 1,
#  'jan': 1,
#  'nepal': 1,
#  'months': 1,
#  'fear': 4,
#  'abuse': 1,
#  'households': 1,
#  'concludes': 1,
#  'calgary': 3,
#  'municipal': 1,
#  'deactivated': 1,
#  'boxer': 1,
#  'feinstein': 1,
#  'move': 2,
#  'homeless': 1,
#  'vets': 1,
#  'campus': 1,
#  'ntanzania': 1,
#  'elephant': 1,
#  'population': 1,
#  'declined': 1,
#  'census': 1,
#  'reveals': 1,
#  'cta': 1,
#  'green': 2,
#  'line': 2,
#  'derails': 2,
#  'calumet': 1,
#  'trafford': 4,
#  'centre': 4,
#  'film': 4,
#  'fans': 4,
#  'angry': 4,
#  'odeon': 4,
#  'cinema': 4,
#  'evacuated': 5,
#  'fight': 4,
#  'flames': 1,
#  'save': 2,
#  'injuries': 4,
#  'south': 5,
#  'side': 1,
#  'orders': 1,
#  'rocky': 3,
#  'veld': 1,
#  'music': 2,
#  'festival': 1,
#  'announces': 1,
#  'refunds': 1,
#  'extreme': 1,
#  'weather': 3,
#  'reid': 2,
#  'lake': 3,
#  'prompts': 3,
#  'campground': 2,
#  'order': 2,
#  'gas': 1,
#  'leak': 1,
#  'forces': 2,
#  'saint': 1,
#  'john': 1,
#  'xcc': 1,
#  'xee': 1,
#  'osha': 1,
#  'officers': 3,
#  'site': 7,
#  'investigating': 2,
#  'noranda': 1,
#  'nee': 1,
#  'recalls': 1,
#  'power': 3,
#  'bar': 1,
#  'battery': 1,
#  'packs': 1,
#  'student': 1,
#  'bedroom': 1,
#  'survive': 1,
#  'analysis': 1,
#  'leonardo': 1,
#  'ambidextrous': 1,
#  'read': 3,
#  'schoolboy': 3,
#  'eyewitness': 3,
#  'illustrated': 1,
#  'history': 2,
#  'bombings': 1,
#  'nkids': 1,
#  'company': 1,
#  'closure': 1,
#  'drop': 1,
#  'expect': 1,
#  'russian': 9,
#  'crematoria': 9,
#  'provoke': 9,
#  'outrage': 9,
#  'amid': 11,
#  'famine': 9,
#  'memories': 13,
#  'content': 2,
#  'warning': 2,
#  'boy': 1,
#  'manslaughter': 1,
#  'shooting': 6,
#  'elijah': 1,
#  'walker': 1,
#  'deputies': 1,
#  'dog': 2,
#  'dispute': 1,
#  'leads': 1,
#  'person': 1,
#  'cops': 1,
#  'immigrant': 1,
#  'prior': 1,
#  'arrests': 1,
#  'sex': 1,
#  'hometown': 1,
#  'austin': 1,
#  'record': 1,
#  'pace': 1,
#  'pedestrian': 1,
#  'worry': 1,
#  'operation': 1,
#  'downfall': 1,
#  'driver': 1,
#  'fatalities': 1,
#  'irish': 1,
#  'roads': 1,
#  'pedestrians': 1,
#  'cyclists': 1,
#  'risk': 2,
#  'died': 1,
#  'lyme': 1,
#  'chances': 1,
#  'mysterious': 1,
#  'loretta': 1,
#  'fuddy': 1,
#  'truck': 2,
#  'clogs': 1,
#  'canyon': 1,
#  'road': 1,
#  'trailer': 1,
#  'catches': 1,
#  'reno': 1,
#  'help': 4,
#  'denver': 2,
#  'working': 2,
#  'curb': 2,
#  'responder': 2,
#  'small': 1,
#  'rock': 1,
#  'springs': 1,
#  'blm': 1,
#  'retention': 1,
#  'ponds': 1,
#  'above': 1,
#  'elk': 1,
#  'street': 1,
#  'residents': 2,
#  'again': 3,
#  'dealt': 1,
#  'issues': 1,
#  'monday': 1,
#  'cuban': 2,
#  'leader': 2,
#  'extends': 2,
#  'sympathy': 2,
#  'vietnam': 4,
#  'business': 1,
#  'sponge': 1,
#  'rain': 1,
#  'reliefweb': 3,
#  'british': 3,
#  'trekkers': 2,
#  'rescued': 7,
#  'himalayas': 2,
#  'queen': 1,
#  'elizabeth': 1,
#  'hospital': 1,
#  'birmingham': 1,
#  'burst': 1,
#  'pipe': 1,
#  'apartments': 2,
#  'nycha': 1,
#  'senior': 1,
#  'monsoon': 1,
#  'kills': 9,
#  'dozens': 3,
#  'myanmar': 2,
#  'prompting': 1,
#  'channel': 1,
#  'prophet': 1,
#  'producer': 1,
#  'songwriter': 1,
#  'rage': 1,
#  'forest': 1,
#  'service': 2,
#  'sounds': 1,
#  'sharply': 1,
#  'costs': 1,
#  'palm': 1,
#  'oil': 28,
#  'peril': 1,
#  'saving': 1,
#  'leuser': 1,
#  'ecosystem': 1,
#  'tthe': 1,
#  'nightmares': 1,
#  'already': 1,
#  'smart': 1,
#  'funny': 1,
#  'fearless': 1,
#  'page': 5,
#  'commuters': 3,
#  'abandoned': 3,
#  'lrt': 3,
#  'station': 3,
#  'severe': 5,
#  'hailstorm': 3,
#  'sky': 1,
#  'castle': 1,
#  'garden': 1,
#  'light': 1,
#  'love': 1,
#  'communication': 1,
#  'future': 1,
#  'touch': 1,
#  'choking': 1,
#  'hazard': 1,
#  'recall': 2,
#  'kraft': 1,
#  'cheese': 1,
#  'singles': 1,
#  'heat': 1,
#  'wave': 1,
#  'adding': 1,
#  'misery': 1,
#  'internally': 1,
#  'gazans': 1,
#  'web': 2,
#  'surfing': 2,
#  'protection': 2,
#  'patrick': 1,
#  'dolan': 1,
#  'critton': 1,
#  'hijacked': 1,
#  'then': 1,
#  'became': 1,
#  'sat': 1,
#  'tutor': 1,
#  'james': 3,
#  'schoenfeld': 2,
#  'allowed': 2,
#  'parole': 3,
#  'bus': 5,
#  'hijacking': 4,
#  'china': 1,
#  'topix': 1,
#  'hijacker': 1,
#  'stands': 1,
#  'localweeklypaper': 1,
#  'celebrity': 15,
#  'murderous': 2,
#  'story': 5,
#  'america': 2,
#  'egyptian': 1,
#  'tied': 1,
#  'isis': 4,
#  'threaten': 1,
#  'croatian': 2,
#  'hostage': 2,
#  'purported': 1,
#  'threatens': 1,
#  'embed': 2,
#  'translate': 2,
#  'gaza': 3,
#  'blast': 2,
#  'house': 2,
#  'leveled': 2,
#  'carterville': 1,
#  'high': 1,
#  'trauma': 2,
#  'involving': 2,
#  'kids': 2,
#  'sport': 2,
#  'usually': 2,
#  'cycling': 2,
#  'related': 2,
#  'negligence': 1,
#  'fireworks': 1,
#  'incidents': 1,
#  'graava': 1,
#  'camera': 1,
#  'uses': 1,
#  'automatically': 1,
#  'edit': 1,
#  'footage': 1,
#  'office': 1,
#  'coastal': 1,
#  'management': 1,
#  'ofertas': 1,
#  'lightning': 1,
#  'strike': 1,
#  'distance': 1,
#  'wild': 2,
#  'horse': 1,
#  'campaign': 1,
#  'nanders': 1,
#  'breivik': 1,
#  'chilling': 1,
#  ...}

# %%
normal_word_count = {}
twt_data_without_error.loc[twt_data_without_error['target'] == 0,'header_splited'].map(
    lambda x: [count_words(word, normal_word_count) for word in x] if (x != None) else None
)
normal_word_count
# Out:
# {'real': 4,
#  'webcam': 2,
#  'babes': 2,
#  'performing': 2,
#  'hot': 4,
#  'live': 4,
#  'cam': 2,
#  'shows': 2,
#  'facebook': 37,
#  'personal': 1,
#  'injury': 3,
#  'lawyer': 1,
#  'sleep': 1,
#  'blog': 6,
#  'icemoon': 7,
#  'aftershock': 8,
#  'these': 1,
#  'five': 2,
#  'minute': 1,
#  'daily': 1,
#  'habits': 1,
#  'seriously': 1,
#  'improve': 1,
#  'life': 3,
#  'protect': 1,
#  'yourself': 1,
#  'profit': 1,
#  'next': 2,
#  'global': 2,
#  'financial': 3,
#  'meltdown': 2,
#  'cindy': 1,
#  'spitzer': 1,
#  'david': 2,
#  'wiedemer': 2,
#  'robert': 1,
#  'hardcover': 1,
#  'emts': 1,
#  'petition': 6,
#  'per': 1,
#  'hour': 1,
#  'minimum': 1,
#  'wage': 1,
#  'content': 15,
#  'warning': 7,
#  'armageddon': 2,
#  'payamps': 1,
#  'secret': 2,
#  'penis': 1,
#  'time': 4,
#  'infantry': 1,
#  'mens': 1,
#  'youth': 1,
#  'military': 2,
#  'army': 1,
#  'sport': 1,
#  'quartz': 1,
#  'analog': 1,
#  'wrist': 1,
#  'watch': 1,
#  'blue': 3,
#  'nylon': 1,
#  'strap': 1,
#  'blu': 1,
#  'mourning': 1,
#  'notices': 1,
#  'stabbing': 1,
#  'arson': 1,
#  'victims': 1,
#  'stir': 1,
#  'politics': 2,
#  'grief': 1,
#  'israel': 1,
#  'snappytv': 1,
#  'features': 1,
#  'twitter': 2,
#  'media': 5,
#  'studio': 1,
#  'trusting': 1,
#  'iran': 1,
#  'stop': 2,
#  'terrorism': 3,
#  'inviting': 1,
#  'arsonist': 1,
#  'join': 1,
#  'fire': 3,
#  'brigade': 1,
#  'martin': 1,
#  'amis': 1,
#  'launches': 1,
#  'fresh': 1,
#  'attack': 1,
#  'muslim': 1,
#  'faith': 1,
#  'saying': 3,
#  'islamic': 1,
#  'states': 1,
#  'less': 1,
#  'evolved': 1,
#  'musician': 2,
#  'kalle': 2,
#  'mattson': 2,
#  'recreates': 2,
#  'classic': 2,
#  'album': 2,
#  'covers': 2,
#  'clever': 2,
#  'music': 2,
#  'avalanche': 2,
#  'front': 2,
#  'row': 1,
#  'lone': 1,
#  'pine': 1,
#  'trees': 1,
#  'growing': 1,
#  'across': 1,
#  'country': 2,
#  'remembrance': 1,
#  'battle': 1,
#  'gallipoli': 1,
#  'years': 3,
#  'ago': 1,
#  'fedex': 8,
#  'longer': 10,
#  'transport': 8,
#  'bioterror': 8,
#  'germs': 8,
#  'wake': 8,
#  'anthrax': 8,
#  'lab': 8,
#  'mishaps': 8,
#  'nchicago': 1,
#  'police': 8,
#  'detained': 1,
#  'thousands': 1,
#  'black': 2,
#  'americans': 2,
#  'interrogation': 1,
#  'facility': 1,
#  'funny': 1,
#  'videos': 2,
#  'grow': 2,
#  'share': 2,
#  'engage': 2,
#  'prysmian': 1,
#  'secures': 1,
#  'contract': 2,
#  'blight': 3,
#  'bank': 1,
#  'wind': 1,
#  'farm': 1,
#  'cleveland': 1,
#  'heights': 2,
#  'shaker': 1,
#  'fight': 1,
#  'house': 2,
#  'door': 1,
#  'coronavirus': 1,
#  'ohio': 1,
#  'revising': 1,
#  'detroit': 1,
#  'count': 1,
#  'dio': 1,
#  'beats': 1,
#  'nightmare': 1,
#  'elm': 1,
#  'street': 2,
#  'remade': 1,
#  'again': 2,
#  'sony': 1,
#  'sets': 1,
#  'date': 1,
#  'stephen': 1,
#  'king': 1,
#  'dark': 1,
#  'tower': 1,
#  'ronda': 1,
#  'rousey': 1,
#  'close': 1,
#  'making': 1,
#  'floyd': 1,
#  'mayweather': 1,
#  'money': 2,
#  'fights': 1,
#  'connect': 1,
#  'todd': 1,
#  'blake': 1,
#  'helps': 1,
#  'fellow': 1,
#  'young': 1,
#  'adult': 1,
#  'cancer': 1,
#  'patients': 1,
#  'find': 1,
#  'adventure': 1,
#  'through': 1,
#  'changing': 1,
#  'experiences': 1,
#  'learn': 1,
#  'truly': 1,
#  'means': 1,
#  'accelereader': 1,
#  'power': 2,
#  'pocket': 2,
#  'experience': 1,
#  'bolsos': 7,
#  'carteras': 7,
#  'para': 7,
#  'mujer': 7,
#  'institute': 1,
#  'peace': 1,
#  'chairman': 1,
#  'wants': 1,
#  'russian': 2,
#  'body': 3,
#  'bags': 3,
#  'fairfax': 2,
#  'firefighter': 2,
#  'placed': 1,
#  'administrative': 1,
#  'leave': 1,
#  'post': 3,
#  'inciting': 1,
#  'violence': 1,
#  'against': 3,
#  'investigating': 1,
#  'should': 2,
#  'put': 1,
#  'soma': 3,
#  'change': 3,
#  'code': 2,
#  'prohibits': 1,
#  'grills': 1,
#  'decks': 1,
#  'residents': 1,
#  'apartments': 1,
#  'condos': 1,
#  'burned': 1,
#  'mocks': 1,
#  'harper': 1,
#  'appearance': 1,
#  'wildfire': 2,
#  'kanger': 1,
#  'coils': 1,
#  'burning': 2,
#  'fast': 1,
#  'parents': 1,
#  'taking': 1,
#  'their': 3,
#  'kids': 1,
#  'man': 2,
#  'one': 2,
#  'year': 3,
#  'old': 2,
#  'thinks': 1,
#  'better': 1,
#  'disney': 1,
#  'world': 5,
#  'creaxion': 1,
#  'lanza': 1,
#  'form': 1,
#  'marketing': 1,
#  'alliance': 1,
#  'covid': 1,
#  'information': 2,
#  'status': 2,
#  'canceling': 2,
#  'deal': 2,
#  'warships': 2,
#  'france': 2,
#  'agrees': 2,
#  'repay': 2,
#  'russia': 3,
#  'borrowers': 1,
#  'concerned': 1,
#  'possible': 2,
#  'interest': 1,
#  'rate': 2,
#  'rise': 1,
#  'pixels': 1,
#  'chris': 1,
#  'columbus': 1,
#  'catastrophe': 1,
#  'kanyuu': 1,
#  'catastrophic': 1,
#  'fallen': 1,
#  'angel': 1,
#  'reveillertm': 1,
#  'emergency': 14,
#  'keep': 4,
#  'ban': 5,
#  'bee': 4,
#  'killing': 4,
#  'pesticides': 4,
#  'chemical': 1,
#  'plant': 1,
#  'long': 2,
#  'term': 2,
#  'effects': 1,
#  'creek': 1,
#  'under': 8,
#  'investigation': 1,
#  'photographer': 3,
#  'brian': 3,
#  'ruebs': 3,
#  'endures': 3,
#  'feet': 3,
#  'climb': 3,
#  'capture': 4,
#  'bride': 3,
#  'groom': 3,
#  'programmering': 1,
#  'survivors': 1,
#  'hampshire': 1,
#  'circus': 1,
#  'tent': 1,
#  'collapse': 3,
#  'recall': 2,
#  'horror': 1,
#  'confusion': 1,
#  'australia': 4,
#  'ashes': 3,
#  'batting': 1,
#  'sparks': 1,
#  'huge': 3,
#  'amount': 1,
#  'trolling': 1,
#  'available': 2,
#  'due': 3,
#  'copyright': 2,
#  'claim': 2,
#  'third': 2,
#  'party': 2,
#  'pomicide': 1,
#  'reacts': 1,
#  'mgn': 1,
#  'africa': 1,
#  'order': 1,
#  'summer': 5,
#  'sessions': 1,
#  'germany': 1,
#  'art': 2,
#  'electronics': 1,
#  'collide': 1,
#  'city': 26,
#  'hosts': 1,
#  'mind': 1,
#  'blowing': 1,
#  'symposium': 1,
#  'latest': 2,
#  'motorsport': 1,
#  'news': 28,
#  'tthief': 1,
#  'broke': 1,
#  'window': 1,
#  'hicksville': 1,
#  'store': 1,
#  'stole': 1,
#  'cell': 1,
#  'phones': 1,
#  'fled': 1,
#  'crashed': 1,
#  'guardrail': 1,
#  'say': 2,
#  'oil': 1,
#  'prices': 1,
#  'crushed': 1,
#  'drivers': 1,
#  'could': 3,
#  'joy': 1,
#  'pump': 1,
#  'bolt': 1,
#  'cyclone': 1,
#  'dual': 1,
#  'outlet': 1,
#  'pack': 1,
#  'coroner': 1,
#  'spokesman': 1,
#  'signs': 1,
#  'drugs': 1,
#  'alcohol': 1,
#  'use': 2,
#  'vroman': 1,
#  'home': 4,
#  'death': 3,
#  'does': 2,
#  'homeowners': 1,
#  'insurance': 2,
#  'cover': 1,
#  'damage': 2,
#  'fence': 1,
#  'architects': 1,
#  'slam': 1,
#  'queen': 1,
#  'wharf': 1,
#  'casino': 1,
#  'site': 2,
#  'warn': 1,
#  'irreparable': 1,
#  'brisbane': 1,
#  'booming': 1,
#  'license': 1,
#  'sales': 1,
#  'show': 1,
#  'florida': 1,
#  'may': 3,
#  'bear': 1,
#  'hunters': 2,
#  'bears': 1,
#  'reinhard': 1,
#  'bonnke': 1,
#  'tells': 1,
#  'nigerian': 1,
#  'raised': 1,
#  'dead': 1,
#  'later': 1,
#  'ferguson': 1,
#  'sees': 1,
#  'asks': 1,
#  'slain': 1,
#  'mexican': 1,
#  'journalist': 1,
#  'unknowingly': 1,
#  'predicted': 1,
#  'own': 1,
#  'transcript': 1,
#  'cdc': 2,
#  'telebriefing': 1,
#  'improved': 1,
#  'infection': 1,
#  'control': 1,
#  'many': 2,
#  'antibiotic': 1,
#  'resistant': 1,
#  'related': 1,
#  'infections': 1,
#  'deaths': 2,
#  'predict': 1,
#  'averted': 1,
#  'walmart': 1,
#  'announces': 2,
#  'infant': 2,
#  'car': 2,
#  'seat': 1,
#  'designed': 1,
#  'prevent': 1,
#  'china': 2,
#  'only': 1,
#  'delaying': 1,
#  'deluge': 1,
#  'dumuzid': 1,
#  'vince': 1,
#  'mcmahon': 1,
#  'once': 1,
#  'billionaire': 1,
#  'reid': 1,
#  'crypto': 1,
#  'tools': 1,
#  'export': 1,
#  'commerce': 1,
#  'department': 2,
#  'withdraws': 1,
#  'proposal': 1,
#  'promises': 1,
#  'rewrite': 1,
#  'clet': 1,
#  'demolish': 2,
#  'laundry': 1,
#  'suites': 1,
#  'offices': 1,
#  'coming': 2,
#  'salvi': 1,
#  'bistro': 1,
#  'firm': 1,
#  'irish': 1,
#  'ring': 1,
#  'fort': 1,
#  'remaining': 1,
#  'sections': 1,
#  'greystone': 1,
#  'psychiatric': 1,
#  'hospital': 1,
#  'demolition': 3,
#  'full': 2,
#  'moon': 1,
#  'july': 2,
#  'set': 1,
#  'saved': 1,
#  'opal': 1,
#  'community': 1,
#  'land': 1,
#  'trust': 1,
#  'canberra': 1,
#  'first': 3,
#  'fluffy': 1,
#  'homes': 1,
#  'schedule': 2,
#  'released': 1,
#  'heroku': 1,
#  'court': 1,
#  'blocks': 1,
#  'india': 1,
#  'backed': 1,
#  'coal': 1,
#  'mine': 1,
#  'times': 1,
#  'love': 1,
#  'derailed': 1,
#  'staying': 1,
#  'track': 1,
#  'similar': 1,
#  'authors': 1,
#  'follow': 1,
#  'ahello': 1,
#  'tiny': 1,
#  'littlebitofbass': 1,
#  'silinski': 1,
#  'sheeran': 1,
#  'free': 1,
#  'hobbit': 1,
#  'desolation': 2,
#  'smaug': 1,
#  'digital': 1,
#  'download': 1,
#  'gin': 1,
#  'william': 1,
#  'struse': 1,
#  'epic': 4,
#  'mile': 1,
#  'mountain': 1,
#  'run': 1,
#  'lake': 1,
#  'map': 1,
#  'problematique': 1,
#  'putin': 1,
#  'plan': 6,
#  'destroy': 1,
#  'western': 1,
#  'food': 4,
#  'masse': 1,
#  'causing': 1,
#  'public': 2,
#  'backlash': 1,
#  'fahrenheit': 1,
#  'disambiguation': 1,
#  'stocks': 1,
#  'clobbered': 1,
#  'authorities': 1,
#  'take': 2,
#  'account': 3,
#  'destruction': 3,
#  'sanctioned': 1,
#  'crackdown': 2,
#  'restricted': 2,
#  'multiplayer': 2,
#  'update': 2,
#  'louder': 2,
#  'pre': 1,
#  'sale': 1,
#  'registration': 1,
#  'ended': 1,
#  'apollo': 2,
#  'brown': 3,
#  'detonate': 2,
#  'feat': 1,
#  'perrie': 1,
#  'edwards': 1,
#  'devastated': 1,
#  'zayn': 1,
#  'malik': 1,
#  'calls': 1,
#  'off': 3,
#  'engagement': 1,
#  'tumblr': 1,
#  'stuart': 1,
#  'broad': 1,
#  'bowls': 1,
#  'metal': 1,
#  'radio': 3,
#  'anything': 1,
#  'else': 2,
#  'xbf': 4,
#  'xbc': 5,
#  'xbd': 6,
#  'xae': 2,
#  'app': 1,
#  'van': 1,
#  'nuys': 1,
#  'neighborhood': 1,
#  'council': 1,
#  'those': 1,
#  'displaced': 1,
#  'disasters': 1,
#  'label': 1,
#  'legal': 1,
#  'remain': 1,
#  'reach': 1,
#  'treasures': 1,
#  'revealed': 2,
#  'california': 2,
#  'drought': 2,
#  'drains': 1,
#  'lakes': 1,
#  'family': 1,
#  'mourns': 1,
#  'drowning': 1,
#  'superhero': 1,
#  'toddler': 1,
#  'rare': 1,
#  'epilepsy': 1,
#  'xac': 2,
#  'xba': 2,
#  'xbe': 1,
#  'xef': 2,
#  'google': 2,
#  'maps': 1,
#  'xaa': 1,
#  'abandon': 1,
#  'hope': 1,
#  'enter': 1,
#  'here': 3,
#  'temptooth': 1,
#  'tooth': 1,
#  'replacement': 1,
#  'product': 1,
#  'oral': 1,
#  'care': 3,
#  'setting': 1,
#  'fund': 1,
#  'easy': 1,
#  'steps': 1,
#  'lean': 1,
#  'thinking': 1,
#  'quicker': 1,
#  'response': 1,
#  'printable': 2,
#  'templates': 2,
#  'end': 1,
#  'reddit': 9,
#  'devise': 1,
#  'evacuation': 2,
#  'create': 1,
#  'kit': 1,
#  'nnhs': 1,
#  'england': 1,
#  'meet': 1,
#  'targets': 1,
#  'entertainment': 1,
#  'county': 1,
#  'overload': 1,
#  'prompts': 2,
#  'during': 3,
#  'celebrations': 1,
#  'ntanzania': 1,
#  'elephant': 1,
#  'population': 1,
#  'declined': 1,
#  'census': 1,
#  'reveals': 1,
#  'question': 1,
#  'anybody': 1,
#  'having': 2,
#  'problem': 1,
#  'circle': 1,
#  'epicentre': 1,
#  'book': 1,
#  'club': 1,
#  'tin': 1,
#  'tesco': 1,
#  'dog': 2,
#  'exploded': 1,
#  'prompted': 1,
#  'complaint': 1,
#  'nhot': 1,
#  'journey': 1,
#  'polandball': 1,
#  'eyewitness': 1,
#  'valued': 1,
#  'gap': 1,
#  'match': 2,
#  'professional': 1,
#  'journalism': 1,
#  'eye': 1,
#  'witness': 1,
#  'abortion': 1,
#  'organ': 1,
#  'harvesting': 1,
#  'planned': 1,
#  'parenthood': 1,
#  'neyewitness': 1,
#  'women': 1,
#  'girls': 1,
#  'rescued': 1,
#  'boko': 1,
#  'haram': 1,
#  'nigeria': 1,
#  'una': 1,
#  'todo': 1,
#  'lamp': 2,
#  'destroyed': 1,
#  'urine': 1,
#  'falls': 1,
#  'misses': 1,
#  'driver': 1,
#  'lifetime': 1,
#  'fear': 1,
#  'internet': 2,
#  'movies': 1,
#  'books': 1,
#  'sex': 1,
#  'ought': 1,
#  'putting': 1,
#  'couples': 1,
#  'pressure': 1,
#  'open': 1,
#  'rfps': 1,
#  'broward': 1,
#  'system': 1,
#  'needs': 1,
#  'save': 1,
#  'event': 1,
#  'responders': 2,
#  'convene': 1,
#  'national': 2,
#  'summit': 1,
#  'awards': 1,
#  'gis': 1,
#  'technology': 1,
#  'lender': 1,
#  'fees': 1,
#  'veterans': 1,
#  'past': 1,
#  'present': 1,
#  'ideas': 1,
#  'hochepot': 1,
#  'boutique': 1,
#  'ofertas': 2,
#  'fires': 1,
#  'rage': 1,
#  'forest': 1,
#  'service': 2,
#  'sounds': 1,
#  'alarm': 1,
#  'sharply': 1,
#  'rising': 1,
#  'costs': 1,
#  'reasons': 1,
#  'obsessed': 1,
#  'cheryl': 1,
#  'cole': 1,
#  'las': 1,
#  'vegas': 1,
#  'hundreds': 1,
#  'commuters': 1,
#  'abandoned': 1,
#  'lrt': 1,
#  'station': 1,
#  'severe': 1,
#  'hailstorm': 1,
#  'civil': 1,
#  'rights': 1,
#  'discrimination': 1,
#  'standardized': 1,
#  'testing': 1,
#  'choking': 2,
#  'hazard': 2,
#  'kraft': 1,
#  'cheese': 1,
#  'singles': 1,
#  'webkenni': 1,
#  'com': 4,
#  'precious': 1,
#  'cargo': 1,
#  'recalls': 1,
#  'piece': 1,
#  'garments': 1,
#  'nchelsea': 1,
#  'swansea': 1,
#  'preview': 1,
#  'betting': 1,
#  'tips': 1,
#  'heat': 1,
#  'wave': 1,
#  'kill': 1,
#  'percent': 2,
#  'mongolia': 1,
#  'crops': 1,
#  'people': 6,
#  'feel': 1,
#  'reserve': 1,
#  'fall': 1,
#  'day': 5,
#  'bug': 4,
#  'fully': 4,
#  'patched': 4,
#  'comes': 4,
#  'active': 4,
#  'exploit': 4,
#  'bypass': 4,
#  'password': 4,
#  'protection': 9,
#  'jeep': 1,
#  'cherokee': 1,
#  'owners': 1,
#  'file': 1,
#  'lawsuit': 1,
#  'fiat': 1,
#  'chrysler': 1,
#  'harman': 1,
#  'hackers': 1,
#  'wirelessly': 1,
#  'hijack': 1,
#  'vehicle': 1,
#  'tgov': 1,
#  'allows': 1,
#  'parole': 1,
#  'chowchilla': 1,
#  'school': 1,
#  'bus': 2,
#  'hijacker': 1,
#  'james': 1,
#  'schoenfeld': 1,
#  'web': 5,
#  'surfing': 5,
#  'recovery': 1,
#  'celebrity': 25,
#  'guide': 26,
#  'mindy': 1,
#  'kaling': 1,
#  'killer': 1,
#  'confidence': 1,
#  'welcome': 1,
#  'rock': 1,
#  'connection': 1,
#  'injured': 1,
#  'barcelona': 1,
#  'alba': 1,
#  'super': 3,
#  'cup': 1,
#  'type': 1,
#  'adhd': 1,
#  'head': 1,
#  'injuries': 1,
#  'children': 1,
#  'linked': 1,
#  'attention': 1,
#  'problems': 1,
#  'espn': 1,
#  'barkevious': 1,
#  'mingo': 1,
#  'missed': 1,
#  'browns': 1,
#  'practice': 1,
#  'mystery': 1,
#  'darren': 1,
#  'mcfadden': 1,
#  'updates': 1,
#  'cowboys': 1,
#  'star': 1,
#  'hamstring': 1,
#  'return': 1,
#  'laois': 2,
#  'girl': 2,
#  'advertised': 2,
#  'friend': 2,
#  'replace': 2,
#  'loved': 2,
#  'bff': 2,
#  'inundated': 2,
#  'republican': 1,
#  'primary': 1,
#  'speaking': 1,
#  'memorable': 1,
#  'debates': 1,
#  'second': 1,
#  'bloomberg': 6,
#  'gotten': 1,
#  'little': 1,
#  'too': 1,
#  'exited': 1,
#  'made': 1,
#  'lava': 2,
#  'placa': 1,
#  'puerto': 2,
#  'pci': 2,
#  'sserial': 1,
#  'computer': 1,
#  'uart': 1,
#  'lightning': 1,
#  'strike': 1,
#  'edition': 4,
#  'issue': 4,
#  'deepak': 1,
#  'chopra': 1,
#  'bad': 1,
#  'bolstering': 1,
#  'cooperation': 1,
#  'asia': 1,
#  'finnish': 1,
#  'ministers': 1,
#  'fennovoima': 1,
#  'nuclear': 3,
#  'reactor': 2,
#  'ahead': 1,
#  'energy': 1,
#  'offers': 1,
#  'mln': 1,
#  'designs': 1,
#  'stuff': 1,
#  'drunk': 3,
#  'meals': 3,
#  'cook': 3,
#  'totally': 3,
#  'obliterated': 3,
#  'nbp': 1,
#  'manage': 1,
#  'executive': 1,
#  'checklist': 1,
#  'jim': 1,
#  'kerr': 1,
#  'altajizzta': 1,
#  'finally': 5,
#  'panicking': 5,
#  'cable': 5,
#  'vinnie': 1,
#  'jones': 1,
#  'goes': 2,
#  'beat': 1,
#  'northumbria': 1,
#  'oops': 1,
#  'bounty': 1,
#  'try': 1,
#  'raid': 1,
#  'phoenix': 1,
#  'chief': 1,
#  'quarantine': 7,
#  'offensive': 7,
#  'policy': 1,
#  'effect': 1,
#  'horrible': 1,
#  'subreddits': 1,
#  'banned': 1,
#  'quarantined': 2,
#  'users': 1,
#  'sub': 1,
#  'turkish': 1,
#  'newlyweds': 2,
#  'donate': 1,
#  'wedding': 2,
#  'syrian': 2,
#  'refugees': 2,
#  'feed': 1,
#  'beginnings': 1,
#  'animal': 1,
#  'rescue': 1,
#  'jersey': 1,
#  'tell': 1,
#  'united': 2,
#  'nations': 1,
#  'plantations': 1,
#  'forests': 1,
#  'quiet': 1,
#  'riot': 1,
#  'well': 1,
#  'way': 1,
#  'inventory': 1,
#  'sandstorm': 1,
#  'edit': 1,
#  'tiran': 1,
#  'supreme': 1,
#  'leader': 1,
#  'screams': 1,
#  'america': 1,
#  'amid': 1,
#  'ongoing': 1,
#  'talks': 1,
#  'exploration': 1,
#  'takes': 1,
#  'seismic': 4,
#  'shift': 2,
#  'gabon': 1,
#  'somalia': 1,
#  'tagency': 1,
#  'seeks': 6,
#  'comments': 1,
#  'permits': 1,
#  'oddball': 1,
#  'sinkhole': 6,
#  'selfies': 3,
#  'wont': 3,
#  'believe': 3,
#  'brooklyn': 3,
#  'fox': 2,
#  'york': 2,
#  'firms': 1,
#  'subject': 1,
#  'cybersecurity': 1,
#  'rules': 7,
#  'marketforce': 1,
#  'perth': 1,
#  ...}

# %%
total_header_words = pd.DataFrame(list(total_word_count.items()), index=range(len(total_word_count.items())),\
                                  columns=['word', 'count'])
disaster_header_words = pd.DataFrame(list(disaster_word_count.items()), index=range(len(disaster_word_count.items())),\
                                  columns=['word', 'count'])
normal_header_words = pd.DataFrame(list(normal_word_count.items()), index=range(len(normal_word_count.items())),\
                                  columns=['word', 'count'])

# %%
words_top_20 = total_header_words.sort_values('count', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'count', y = 'word', data=words_top_20)
g.set_title("Top 20 de las palabras mas mencionadas en los titulos", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Palbras", fontsize=14)
# Out:
# Text(0, 0.5, 'Palbras')

# %%
words_top_20 = disaster_header_words.sort_values('count', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'count', y = 'word', data=words_top_20)
g.set_title("Top 20 de las palabras mas mencionadas en los titulos durante un desastre", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Palabras", fontsize=14)
# Out:
# Text(0, 0.5, 'Palabras')

# %%
words_top_20 = normal_header_words.sort_values('count', ascending=False).head(20).reset_index()
g = sns.barplot(x = 'count', y = 'word', data=words_top_20)
g.set_title("Top 20 de las palabras mas mencionadas en los titulos durante la normalidad", fontsize=16, pad=20)
g.set_xlabel("Cantidad", fontsize=14)
g.set_ylabel("Palabras", fontsize=14)
# Out:
# Text(0, 0.5, 'Palabras')

# %%
def disaster_color_fun(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    pot = - (4/font_size)
    percentage = pow(10, pot)
    return "hsl(22, %d%%, 48%%)" % (100 * percentage)

# %%
def normal_color_fun(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    pot = - (4/font_size)
    percentage = pow(10, pot)
    return "hsl(166, %d%%, 35%%)" % (100 * percentage)

# %%
normal_color
# Out:
# (0.0, 0.7, 0.5320000000000001)

# %%
#palabras mas usadas en tweets no tienen que ver con desastres reales
wordcloud = WordCloud(width = 500, height = 500, min_font_size = 5, max_font_size = 70, max_words = 1000, 
                      background_color = 'black', stopwords = list_stopwords).generate_from_frequencies(normal_word_count)
fig = plt.figure(
    figsize = (10, 7),
    facecolor = 'k')
plt.imshow(wordcloud.recolor(color_func=normal_color_fun, random_state=3), interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.title('Palabras que aparecen en las paguinas linkeadas a tweets referidos a desastre')
plt.show()

# %%
#palabras mas usadas en tweets no tienen que ver con desastres reales
wordcloud = WordCloud(width = 500, height = 500, min_font_size = 5, max_font_size = 70, max_words = 1000, 
                      background_color = 'black', stopwords = list_stopwords)\
                        .generate_from_frequencies(disaster_word_count)
fig = plt.figure(
    figsize = (10, 7),
    facecolor = 'k')
plt.imshow(wordcloud.recolor(color_func=disaster_color_fun, random_state=3), interpolation="bilinear")
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
g = sns.distplot(list(disaster_word_count.values()), hist=True, kde=False, bins=15, color=disaster_color)
g.set_title('Distribucion de la cantidad de veces que aparece una palabra durante un desastre',\
            fontsize=16, pad=20)
g.set_ylabel('Frecuencia', fontsize=18)
g.set_yscale('log')
g.set_xlabel('Cantidad de apariciones', fontsize=18)
# Out:
# Text(0.5, 0, 'Cantidad de apariciones')

# %%
g = sns.distplot(list(normal_word_count.values()), hist=True, kde=False, bins=15, color=normal_color)
g.set_title('Distribucion de la cantidad de veces que aparece una palabra durante un normalidad',\
            fontsize=16, pad=20)
g.set_ylabel('Frecuencia', fontsize=18)
g.set_yscale('log')
g.set_xlabel('Cantidad de apariciones', fontsize=18)
# Out:
# Text(0.5, 0, 'Cantidad de apariciones')
