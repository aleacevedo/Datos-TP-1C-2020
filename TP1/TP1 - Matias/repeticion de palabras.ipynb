# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
import re
import random

# %matplotlib inline

plt.style.use('default')
plt.rcParams['figure.figsize'] = (8,5)

sns.set(style="whitegrid")

pd.options.display.float_format = '{:20,.2f}'.format

import warnings
warnings.filterwarnings('ignore')

# %%
tweets = pd.read_csv("../data/train.csv")

# %%
tweets.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
# id          7613 non-null int64
# keyword     7552 non-null object
# location    5080 non-null object
# text        7613 non-null object
# target      7613 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %%
tweets["text"].value_counts()
# Out:
# 11-Year-Old Boy Charged With Manslaughter of Toddler: Report: An 11-year-old boy has been charged with manslaughter over the fatal sh...           10
# The Prophet (peace be upon him) said 'Save yourself from Hellfire even if it is by giving half a date in charity.'                                  6
# #Bestnaijamade: 16yr old PKK suicide bomber who detonated bomb in ... http://t.co/KSAwlYuX02 bestnaijamade bestnaijamade bestnaijamade beÛ_        6
# He came to a land which was engulfed in tribal war and turned it into a land of peace i.e. Madinah. #ProphetMuhammad #islam                         6
# Madhya Pradesh Train Derailment: Village Youth Saved Many Lives                                                                                     5
# VIDEO: 'We're picking up bodies from water': Rescuers are searching for hundreds of migrants in the Mediterranean after a boat carryi...            4
# .POTUS #StrategicPatience is a strategy for #Genocide; refugees; IDP Internally displaced people; horror; etc. https://t.co/rqWuoy1fm4              4
# To fight bioterrorism sir.                                                                                                                          4
# that horrible sinking feeling when youÛªve been at home on your phone for a while and you realise its been on 3G this whole time                   4
# @spinningbot Are you another Stand-user? If you are I will have to detonate you with my Killer Queen.                                               3
# Who is bringing the tornadoes and floods. Who is bringing the climate change. God is after America He is plaguing her\n \n#FARRAKHAN #QUOTE         3
# Beware of your temper and a loose tongue! These two dangerous weapons combined can lead a person to the Hellfire #islam!                            3
# Hellfire is surrounded by desires so be careful and donÛªt let your desires control you! #Afterlife                                                3
# #foodscare #offers2go #NestleIndia slips into loss after #Magginoodle #ban unsafe and hazardous for #humanconsumption                               3
# #Allah describes piling up #wealth thinking it would last #forever as the description of the people of #Hellfire in Surah Humaza. #Reflect          3
# Wreckage 'Conclusively Confirmed' as From MH370: Malaysia PM                                                                                        3
# @TinyJecht Are you another Stand-user? If you are I will have to detonate you with my Killer Queen.                                                 3
# CLEARED:incident with injury:I-495  inner loop Exit 31 - MD 97/Georgia Ave Silver Spring                                                            3
# Madhya Pradesh Train Derailment: Village Youth Saved Many Lives: A group of villagers saved over 70 passengers' lives after two train...            3
# wowo--=== 12000 Nigerian refugees repatriated from Cameroon                                                                                         2
# Burning buildings? Media outrage? http://t.co/pHixZnv1YN                                                                                            2
# I'm mentally preparing myself for a bomb ass school year if it's not I'm burning buildings ??                                                       2
# 'Suicide bombing at [location named]...' #premonitions http://t.co/iIkSsJGBDn                                                                       2
# General News Û¢åÊ'Demolition of houses on waterways begins at Achimota Mile 7 ' via @233liveOnline. Full story at http://t.co/iO7kUUg1uq           2
# like for the music video I want some real action shit like burning buildings and police chases not some weak ben winston shit                       2
# that exploded &amp; brought about the\nbeginning of universe matches what's\nmentioned in the versethe heaven and Earth\n(thus the universe)        2
# RT AbbsWinston: #Zionist #Terrorist kidnapped 15 #Palestinians in overnight terror on Palestinian Villages Û_ http://t.co/J5mKcbKcov               2
# @aria_ahrary @TheTawniest The out of control wild fires in California even in the Northern part of the state. Very troubling.                       2
# #KCA #VoteJKT48ID 12News: UPDATE: A family of 3 has been displaced after fired damaged housed near 90th and Osborn. Fire extinguished no iÛ_       2
# M1.94 [01:04 UTC]?5km S of Volcano Hawaii. http://t.co/zDtoyd8EbJ                                                                                   2
#                                                                                                                                                    ..
# GREAT PERFORMANCE CHIP FUEL/GAS SAVER CHEVY TAHOE/BLAZER/AVALANCHE/S-10 http://t.co/iCrZi5TqC5 http://t.co/ONxhKfHn2a                               1
# Finnish ministers: Fennovoima nuclear reactor will go ahead via /r/worldnews http://t.co/fRkOdEstuK                                                 1
# Wreckage 'Conclusively Confirmed' as From MH370: Malaysia PM: Investigators and the families of those who were... http://t.co/gRh7zLK979            1
# Christian Attacked by Muslims at the Temple Mount after Waving Israeli Flag via Pamela Geller - ... http://t.co/U0kEOe5fMt                          1
# Emergency Response and Hazardous Chemical Management: Principles and Practices http://t.co/4sSuyhkgRB http://t.co/TDerBtgZ2k                        1
# #kick #hurricane Seriously #simple websites: http://t.co/x8W7tF6FHg Looking For A Seriously Simple Program To http://t.co/9NZ9zFM93i                1
# RT @danielkemp6 Likened to THE 39 STEPS and The GOOD SHEPHERD by the FILM producer THE DESOLATE GARDEN on ALL here  http://t.co/fel4QhWyFD          1
# (?EudryLantiqua?) Hollywood Movie About Trapped Miners Released in Chile: 'The 33' Holly... http://t.co/us1DMdXZVb (?EudryLantiqua?)                1
# Let's say a tree falls on your fence. Do you know how your homeowners insurance may help? http://t.co/VLaIuvToMM http://t.co/AJpnEBG803             1
# If it wasn't for the Blood! ????                                                                                                                    1
# Womens Buckle Casual Stylish Shoulder Handbags Pockets Cross Body Bags Green http://t.co/pYee94nuRe                                                 1
# They absolutely demolished the sounders from start to finish                                                                                        1
# FYI CAD:FYI: ;ACCIDENT PROPERTY DAMAGE;WPD;1600 S 17TH ST                                                                                           1
# One thing you can be sure of. There will never be bush fires in Scotland as the ground is always soaking wet????                                    1
# New post from @darkreading http://t.co/8eIJDXApnp New SMB Relay Attack Steals User Credentials Over Internet                                        1
# @StevenOnTwatter @PussyxDestroyer just order a blizzard pay then put your nuts in it say they have you ball flavored. Boom free ice cream           1
# #bioterrorism Authorities allay #glanders fears ahead of Rio Olympic equestrian test event http://t.co/UotPNSQpz5 via @HorsetalkNZ                  1
# gonna drown it in mustard and lemon pepper :)                                                                                                       1
# #TheaterShooting DEFENDANT/MASS MURDERER CHOSE NOT 2 TESTIFY IN FINAL PHASE 3 so he won't therefore B subject 2 cross-exam or jury questions        1
# 30 seconds for my bitches to evacuate ??????                                                                                                        1
# Progressive greetings!\n\nIn about a month students would have set their pens ablaze in The Torch Publications'... http://t.co/9FxPiXQuJt           1
# Investigators shift focus to cause of fatal Waimate fire http://t.co/GoeTJGIhOp                                                                     1
# 'Anyway' the old lady went on 'I have something to ask of you - and you alone.' THE COMING TSUNAMI http://t.co/tYeWZf3hqA                           1
# Still can't get over the thunderstorm/tornado we were woken up to yesterday. Half the street is still in the dark! http://t.co/Y8h5v1j2y7           1
# 'We are now prepared to obliterate more rapidly and completely every productive enterprise the Japanese have above ground in any city.'             1
# A GPM satellite 'bullseye' in Typhoon Soudelor http://t.co/7vcEzi6CbB                                                                               1
# Large fire burning several buildings causing evacuations in downtown Hinton: http://t.co/mtMkiMwiyy                                                 1
# UPDATE:M.E. confirms 2 women pulled from burning house died last Friday. 91 yr old Edna Jefferson&amp;Doris Sherfield72. http://t.co/L6nSLzl7mI     1
# This is the natural and unavoidable consequence of socialism everywhere it has been tried.\nhttp://t.co/BbDpnj8XSx A                                1
# Rly tragedy in MP: Some live to recount horror: ÛÏWhen I saw coaches of my train plunging into water I called ... http://t.co/0Xh758OnUP           1
# Name: text, Length: 7503, dtype: int64

# %%
#repeticion_de_palabras
tweets["text"] = tweets["text"].str.lower() #transformo todas las palabras a minuscula
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'[^\w]', ' ', x)) #quito todos los caracteres no alfanumericos
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'_', ' ', x))
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'[0-9]',' ', x)) #quito los caracteres numericos
tweets["text"] = tweets["text"].apply(lambda s: re.sub(r'\b\w{1}\b', '', s)) #quito las letras sueltas
tweets["text"] = tweets["text"].apply(lambda x: re.sub(' +',' ', x)) #quito los espacios de mas
tweets.tail()
# Out:
#          id keyword location  \
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 7608  two giant cranes holding bridge collapse into ...       1
# 7609   aria ahrary thetawniest the out of control wi...       1
# 7610        utc km of volcano hawaii http co zdtoyd ebj       1
# 7611  police investigating after an bike collided wi...       1
# 7612  the latest more homes razed by northern califo...       1

# %%
tweets["words_count"] = tweets["text"].str.split(' ').apply(lambda x: len(x))
tweets.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  our deeds are the reason of this earthquake ma...
# 1   4     NaN      NaN              forest fire near la ronge sask canada
# 2   5     NaN      NaN  all residents asked to shelter in place are be...
# 3   6     NaN      NaN   people receive wildfires evacuation orders in...
# 4   7     NaN      NaN  just got sent this photo from ruby alaska as s...
#
#    target  words_count
# 0       1           13
# 1       1            7
# 2       1           22
# 3       1            9
# 4       1           16

# %%
tweets["words_count"].hist(bins=30, color="lightblue")
plt.title("Frecuencia de cantidades de palabras en tweets", fontsize=17, fontweight="bold")
plt.xlabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0.5, 0, 'Cantidad de palabras')

# %%
tweets["keyword"] = tweets["keyword"].str.replace('%20',' ')

# %%
tweets_falsos = tweets[tweets["target"]==0]
tweets_verdaderos = tweets[tweets["target"]==1]

# %%
tweets_verdaderos["words_count"].hist(bins=28, color="green")
plt.title("Frecuencia de cantidades de palabras en tweets sobre desastres reales", fontsize=17, fontweight="bold")
plt.xlabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0.5, 0, 'Cantidad de palabras')

# %%
tweets_falsos["words_count"].hist(bins=30, color="red")
plt.title("Frecuencia de cantidades de palabras en tweets que no refieren a desastres", fontsize=15, fontweight="bold")
plt.xlabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0.5, 0, 'Cantidad de palabras')

# %%
g = sns.kdeplot(tweets_verdaderos["words_count"], color="green", label="Tweets de desastres reales", shade=True)
g = sns.kdeplot(tweets_falsos["words_count"], color="red", label="Tweets de desastres no reales", shade=True)
g.set_title("Distribución de la cantidad de palabras en tweets", fontsize=17, fontweight="bold")
g.set_ylabel("Densidad", fontsize=12)
g.set_xlabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0.5, 0, 'Cantidad de palabras')

# %%
#poner estadisticas de cantidad de palabras (agrupando por target) por ejemplo la suma y mostrar esa suma con un barplot por target
#poner esto antes de ver las palabras en el wordcloud
grouped_by_target = tweets.groupby(["target"]).agg({"words_count":["sum","max","min","mean"]})
grouped_by_target.rename(columns={"words_count":"valor"}, inplace=True)
grouped_by_target.stack()
# Out:
#                            valor
# target
# 0      max                 31.00
#        mean                15.92
#        min                  1.00
#        sum             69,108.00
# 1      max                 29.00
#        mean                17.05
#        min                  2.00
#        sum             55,784.00

# %%
g = sns.boxplot(x="target", y="words_count", data= tweets, palette="Set1")
g.set_title("Cantidad de palabras segun el target", fontsize=15, fontweight="bold")
g.set_xlabel("Target", fontsize=10)
g.set_ylabel("Cantidad de palabras", fontsize=10)
# Out:
# Text(0, 0.5, 'Cantidad de palabras')

# %%
#Miro cantidad de palabras por keyword
tweets_con_keywords = tweets[~tweets["keyword"].isnull()]
print(len(tweets_con_keywords))
tweets_con_keywords.head(10)
# Out:
# 7552
#     id keyword                       location  \
# 31  48  ablaze                     Birmingham
# 32  49  ablaze  Est. September 2012 - Bristol
# 33  50  ablaze                         AFRICA
# 34  52  ablaze               Philadelphia, PA
# 35  53  ablaze                     London, UK
# 36  54  ablaze                       Pretoria
# 37  55  ablaze                   World Wide!!
# 38  56  ablaze                            NaN
# 39  57  ablaze                 Paranaque City
# 40  59  ablaze                 Live On Webcam
#
#                                                  text  text_length  target  \
# 31     bbcmtd wholesale markets ablaze http lhyxeohy            50       1
# 32     always try bring the heavy metal http yao xngw           58       0
# 33   africanbaze breaking news nigeria flag set ab...           75       1
# 34                     crying out for more set ablaze           33       0
# 35   plus side look the sky last night was ablaze ...           71       0
# 36   phdsquares mufc they built much hype around n...          119       0
# 37         inec office abia set ablaze http imaomknna           48       1
# 38  barbados bridgetown jamaica two cars set ablaz...          125       1
# 39                               ablaze for you lord            20       0
# 40  check these out http roi nsmejj http zjin http...           92       0
#
#     words_count
# 31            9
# 32           13
# 33           13
# 34            7
# 35           16
# 36           23
# 37            9
# 38           22
# 39            5
# 40           19

# %%
top10_keywords = tweets["keyword"].value_counts().head(10).index.tolist()
top10_keywords
# Out:
# ['fatalities',
#  'armageddon',
#  'deluge',
#  'body bags',
#  'sinking',
#  'damage',
#  'harm',
#  'evacuate',
#  'outbreak',
#  'collided']

# %%
tweets_top10_keywords = tweets[tweets["keyword"].isin(top10_keywords)]
tweets_top10_keywords["keyword"].value_counts()
# Out:
# fatalities    45
# deluge        42
# armageddon    42
# harm          41
# body bags     41
# sinking       41
# damage        41
# collided      40
# outbreak      40
# evacuate      40
# Name: keyword, dtype: int64

# %%
grouped = tweets_top10_keywords.groupby(["keyword","target"]).agg({"words_count":["sum","max","min"]})
grouped
# Out:
#                   words_count
#                           sum max min
# keyword    target
# armageddon 0              588  27   3
#            1               76  23   5
# body bags  0              651  26   4
#            1               19  19  19
# collided   0              320  29   5
#            1              446  24  11
# damage     0              340  28   5
#            1              299  28   5
# deluge     0              651  28   7
#            1              120  25  10
# evacuate   0              222  24   5
#            1              450  27  10
# fatalities 0              307  23   8
#            1              468  25  10
# harm       0              672  27   7
#            1               89  26  17
# outbreak   0               24  24  24
#            1              767  25  12
# sinking    0              596  28   4
#            1              154  24  12

# %%
ax = sns.swarmplot(x="keyword", y="words_count", hue="target", data=tweets_top10_keywords)
ax.legend(loc="upper center", bbox_to_anchor=(1.1,1))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, 'armageddon'),
#  Text(0, 0, 'body bags'),
#  Text(0, 0, 'collided'),
#  Text(0, 0, 'damage'),
#  Text(0, 0, 'deluge'),
#  Text(0, 0, 'evacuate'),
#  Text(0, 0, 'fatalities'),
#  Text(0, 0, 'harm'),
#  Text(0, 0, 'outbreak'),
#  Text(0, 0, 'sinking')]

# %%
#agrego la columna de la longitud del texto
tweets.insert(loc=tweets.columns.get_loc("text")+1, column="text_length", value= tweets["text"].str.len())
tweets.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  our deeds are the reason of this earthquake ma...
# 1   4     NaN      NaN              forest fire near la ronge sask canada
# 2   5     NaN      NaN  all residents asked to shelter in place are be...
# 3   6     NaN      NaN   people receive wildfires evacuation orders in...
# 4   7     NaN      NaN  just got sent this photo from ruby alaska as s...
#
#    text_length  target  words_count
# 0           68       1           13
# 1           37       1            7
# 2          130       1           22
# 3           58       1            9
# 4           84       1           16

# %%
list_stopwords = ["the","and","you","for","that","with","this","from","are","have","was","like","but","just","not","your",\
                 "all","after","will","can","has","when","they","get","new","now","what","amp","","http","https","out",\
                 "more","about","how","there","don","over","into","than","would","been","her","who","were","some","still",\
                 "his","back","why","them","got","know","had","see","going","our","htt","via","nws","wait",\
                 "hwy","top","both","hah","haha","getting","far","near"]

# %%
tweets["text"] = tweets["text"].apply(lambda s: re.sub(r'\b\w{1,2}\b', '', s)) #quito las palabras cortas
tweets["text"] = tweets["text"].apply(lambda x: re.sub(' +',' ', x))
tweets.loc[:,["text"]].tail()
# Out:
#                                                    text
# 7608  two giant cranes holding bridge collapse into ...
# 7609   aria ahrary thetawniest the out control wild ...
# 7610                 utc volcano hawaii http zdtoyd ebj
# 7611  police investigating after bike collided with ...
# 7612  the latest more homes razed northern californi...

# %%
tweets_falsos = tweets[tweets["target"]==0]
tweets_verdaderos = tweets[tweets["target"]==1]

# %%
def twitter_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(5, 100%%, %d%%)" % random.randint(60,100)

# %%
def twitter_color_func2(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(125, 100%%, %d%%)" % random.randint(60,100)

# %%
#palabras mas usadas en tweets no tienen que ver con desastres reales
mask = np.array(Image.open("../data/Twitter-Logo.jpg"))
wordcloud = WordCloud(width = 500, height = 500, min_font_size = 5, max_font_size = 70, max_words = 1000, 
                      background_color = 'black', mask= mask, stopwords = list_stopwords).\
                        generate(str(tweets_falsos["text"]))
fig = plt.figure(
    figsize = (10, 7),
    facecolor = 'k')
plt.imshow(wordcloud.recolor(color_func = twitter_color_func, random_state=3), interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#palabras mas usadas en tweets no tienen que ver con desastres reales
mask = np.array(Image.open("../data/Twitter-Logo.jpg"))
wordcloud = WordCloud(width = 500, height = 500, min_font_size = 5, max_font_size = 70, max_words = 1000, 
                      background_color = 'black', mask= mask, stopwords = list_stopwords).\
                        generate(str(tweets_verdaderos["text"]))
fig = plt.figure(
    figsize = (10, 7),
    facecolor = 'k')
plt.imshow(wordcloud.recolor(color_func = twitter_color_func2, random_state=3), interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
#evaluaremos la relacion entre la longitud del tweet y la cantidad de palabras del mismo
tweets.loc[:,["text","text_length","words_count"]].sort_values(by="text_length", ascending=False).head(10)
# Out:
#                                                    text  text_length  \
# 5096  we want to see no more hiroshima and nagasaki ...          142
# 5379  savs contact fell out but she was convinced it...          141
# 7460   icymagistrate ûóher upper arm ûò those friggi...          141
# 1333  the mv should just be them strutting like they...          140
# 6255  lrt refer to the lyrics to hear big boi explai...          140
# 4943   lt meltdown of proportions commences manage t...          140
# 2272  doone silver architects has won permission to ...          139
# 3836  after shooting event at the theater starbucks ...          139
# 4815  the media needs to stop publicizing mass murde...          139
# 6644  the pak terrorist who has been caught alive mu...          139
#
#       words_count
# 5096           25
# 5379           27
# 7460           24
# 1333           27
# 6255           28
# 4943           28
# 2272           23
# 3836           20
# 4815           28
# 6644           26

# %%
tweets.loc[:,["text","text_length","words_count"]].sort_values(by="words_count", ascending=False).head(10)
# Out:
#                                                    text  text_length  \
# 3859   chose you so if we can search for the joy of ...          138
# 7450   fevwarrior in the vault that could take look ...          132
# 7220   sorry but if you have to resort to weapons to...          133
# 1831  this guy bought my car on tuesday police knock...          132
# 1727  drob collided into dan hughes while she was go...          133
# 1565   leezy its like you re about to fall down clif...          128
# 965    tr jdavis bruh you wanna fight down meet me i...          130
# 945    princessduck last week wanted the th sense to...          132
# 6005   ollymursaus do feel sorry for him he is not p...          126
# 1619  spot fixing match fixing anyone or it has to b...          130
#
#       words_count
# 3859           31
# 7450           29
# 7220           29
# 1831           29
# 1727           29
# 1565           29
# 965            29
# 945            29
# 6005           29
# 1619           29

# %%
g = sns.scatterplot(x="text_length", y="words_count", data=tweets, color="darkblue", edgecolor="lightblue")
g.set_title("Relacion entre longitud del tweet y cantidad de palabras", fontsize=17, fontweight="bold")
g.set_xlabel("Longitud del texto", fontsize=12)
g.set_ylabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0, 0.5, 'Cantidad de palabras')

# %%
g = sns.scatterplot(x="text_length", y="words_count", hue="target", data=tweets, palette="Set1", alpha=0.35)
g.set_title("Relacion entre longitud del tweet y cantidad de palabras segun el target", fontsize=17, fontweight="bold")
g.set_xlabel("Longitud del texto", fontsize=12)
g.set_ylabel("Cantidad de palabras", fontsize=12)
# Out:
# Text(0, 0.5, 'Cantidad de palabras')

# %%
ax = tweets.plot.hexbin(x="text_length", y="words_count", gridsize=25, cmap="bone")
ax.set_title("Relacion entre longitud del tweet y cantidad de palabras", fontsize=15, fontweight="bold")
ax.set_xlabel("Longitud del texto", fontsize=9)
ax.set_ylabel("Cantidad de palabras", fontsize=9)
# Out:
# Text(0, 0.5, 'Cantidad de palabras')

# %%
tweets_con_locations = tweets[~tweets["location"].isnull()]

# %%
#repeticiones de palabras en la columna LOCATION
wordcloud = WordCloud(width = 500, height = 500, min_font_size = 5, max_font_size = 70, max_words = 100, 
                      background_color = 'black', stopwords = STOPWORDS).generate(str(tweets_con_locations["location"]))
fig = plt.figure(
    figsize = (10, 7),
    facecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
tweets["text"] = tweets["text"].str.lower()                                  #convierto todas las letras a minuscula
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'[^\w]', ' ', x))    #remuevo todos los caracteres no alfanumericos
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'_', ' ', x))        #remuevo todos los guiones bajo que quedaron
tweets["text"] = tweets["text"].apply(lambda x: re.sub(r'[0-9]',' ', x))     #remuevo los caracteres numericos
tweets["text"] = tweets["text"].apply(lambda s: re.sub(r'\b\w{1}\b', '', s)) #remuevo todas las letras que quedaron sueltas
tweets["text"] = tweets["text"].apply(lambda x: re.sub(' +',' ', x))         #remuevo los espacios de mas

# %%
tweets_falsos["words_count"].value_counts()
# Out:
# 22    262
# 19    258
# 20    257
# 17    244
# 21    240
# 18    238
# 14    229
# 16    225
# 15    221
# 13    209
# 12    207
# 11    190
# 24    183
# 23    183
# 9     165
# 8     159
# 10    145
# 7     132
# 6     120
# 25    116
# 26     87
# 5      81
# 4      59
# 27     43
# 3      41
# 28     24
# 2      13
# 29      5
# 1       5
# 31      1
# Name: words_count, dtype: int64

# %%
tweets_verdaderos["words_count"].median()
# Out:
# 18.0

# %%
tweets_falsos["words_count"].median()
# Out:
# 16.0
