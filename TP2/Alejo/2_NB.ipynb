# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import random
import re

pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

import warnings
warnings.filterwarnings('ignore')

# %%
train_data = pd.read_csv('~/Documents/Datos/DataSets/TP2/train_featured.csv')
test_data = pd.read_csv('~/Documents/Datos/DataSets/TP2/test_featured.csv')
train_data.head()
# Out:
#    id_original keyword_original location_original  \
# 0            1              NaN               NaN
# 1            4              NaN               NaN
# 2            5              NaN               NaN
# 3            6              NaN               NaN
# 4            7              NaN               NaN
#
#                                        text_original  target_label  \
# 0  our deeds are the reason of this earthquake ma...             1
# 1              forest fire near la ronge sask canada             1
# 2  all residents asked to shelter in place are be...             1
# 3  people receive wildfires evacuation orders in ...             1
# 4  just got sent this photo from ruby alaska as s...             1
#
#    special_chars_count             hashtags labels  hashtags_count  \
# 0                    1         #earthquake     NaN               1
# 1                    1                  NaN    NaN               0
# 2                    3                  NaN    NaN               0
# 3                    2          #wildfires     NaN               1
# 4                    2  #alaska #wildfires     NaN               2
#
#    labels_count  num_chars_count  links_count  \
# 0             0                0            0
# 1             0                0            0
# 2             0                0            0
# 3             0                5            0
# 4             0                0            0
#
#                                           clean_text  text_length  \
# 0       deeds reason earthquake may allah forgive us           68
# 1              forest fire near la ronge sask canada           37
# 2  residents asked shelter place notified officer...          130
# 3  people receive wildfires evacuation orders cal...           56
# 4  got sent photo ruby alaska smoke wildfires pou...           85
#
#       mean_word_length  vowels_count  short_words_count  stopwords_count  \
# 0                 4.31            25                  7                6
# 1                 4.43            13                  1                0
# 2                 4.95            45                  9               11
# 3                 7.14            24                  1                1
# 4                 4.38            25                  3                7
#
#    words_count
# 0           13
# 1            7
# 2           22
# 3            7
# 4           16

# %%
#from sklearn.feature_extraction.text import CountVectorizer
#from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
#from sklearn.pipeline import Pipeline
#from sklearn.linear_model import SGDClassifier
#from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text  import TfidfVectorizer

# %% [raw]
# count_vect = CountVectorizer(stop_words='english')
# X_train_counts = count_vect.fit_transform(train_data['clean_text'])
# X_train_counts.shape

# %% [raw]
# tfidf_transformer = TfidfTransformer()
# X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
# X_train_tfidf.shape

# %% [raw]
# text_clf = Pipeline([('vect', CountVectorizer()),
#                      ('tfidf', TfidfTransformer()),
#                      ('clf', MultinomialNB()),
#                     ])

# %% [raw]
# text_clf = text_clf.fit(train.clean_text, train.target_label)

# %% [raw]
# predicted = text_clf.predict(test.clean_text)
# np.mean(predicted == test.target_label)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train_data.clean_text)
tf_idf = pd.DataFrame(data = X.toarray(), columns=vectorizer.get_feature_names())
tf_idf

# %%
tf_idf_featured = pd.concat([train_data, tf_idf], axis=1)
tf_idf_featured

# %%
tf_idf_featured.drop(['index', 'id_original', 'text_original', 'clean_text', 'keyword_original', 'location_original', 'hashtags', 'labels'], axis=1, inplace=True)

# %%
train, test = train_test_split(tf_idf_featured, test_size=0.2)

# %%
clf = MultinomialNB()
clf.fit(train.drop(['target_label'], axis=1), train.target_label)

# %%
predicted = clf.predict(test.drop(['target_label'], axis=1))
np.mean(predicted == test.target_label)

# %%
test_data.head()
# Out:
#    id_original keyword_original location_original  \
# 0            0              NaN               NaN
# 1            2              NaN               NaN
# 2            3              NaN               NaN
# 3            9              NaN               NaN
# 4           11              NaN               NaN
#
#                                        text_original  special_chars_count  \
# 0                  just happened  terrible car crash                    0
# 1  heard about earthquake is different cities sta...                    3
# 2  there is  forest fire at spot pond geese are f...                    2
# 3              apocalypse lighting spokane wildfires                    3
# 4         typhoon soudelor kills in china and taiwan                    0
#
#                hashtags labels  hashtags_count  labels_count  num_chars_count  \
# 0                   NaN    NaN               0             0                0
# 1          #earthquake     NaN               1             0                0
# 2                   NaN    NaN               0             0                0
# 3  #spokane #wildfires     NaN               2             0                0
# 4                   NaN    NaN               0             0                2
#
#    links_count                                         clean_text  \
# 0            0                        happened terrible car crash
# 1            0  heard earthquake different cities stay safe ev...
# 2            0  forest fire spot pond geese fleeing across str...
# 3            0              apocalypse lighting spokane wildfires
# 4            0                typhoon soudelor kills china taiwan
#
#    text_length     mean_word_length  vowels_count  short_words_count  \
# 0           34                 4.83            10                  2
# 1           61                 5.89            24                  1
# 2           94                 4.00            31                  7
# 3           37                 8.50            12                  0
# 4           42                 5.14            14                  2
#
#    stopwords_count  words_count
# 0                2            6
# 1                2            9
# 2                9           19
# 3                0            4
# 4                2            7

# %%
train_data.tail()
# Out:
#       id_original keyword_original location_original  \
# 7608        10869              NaN               NaN
# 7609        10870              NaN               NaN
# 7610        10871              NaN               NaN
# 7611        10872              NaN               NaN
# 7612        10873              NaN               NaN
#
#                                           text_original  target_label  \
# 7608  two giant cranes holding  bridge collapse into...             1
# 7609  aria ahrary thetawniest the out of control wil...             1
# 7610                          utc km  of volcano hawaii             1
# 7611  police investigating after an  bike collided w...             1
# 7612  the latest more homes razed by northern califo...             1
#
#       special_chars_count hashtags                      labels  \
# 7608                    5      NaN                         NaN
# 7609                    5      NaN  @aria_ahrary @thetawniest
# 7610                   11      NaN                         NaN
# 7611                    5      NaN                         NaN
# 7612                    7      NaN                         NaN
#
#       hashtags_count  labels_count  num_chars_count  links_count  \
# 7608               0             0                1            1
# 7609               0             2                1            0
# 7610               0             0                9            1
# 7611               0             0                0            0
# 7612               0             0                2            1
#
#                                              clean_text  text_length  \
# 7608  two giant cranes holding bridge collapse nearb...           60
# 7609  control wild fires california even northern pa...          121
# 7610                              utc km volcano hawaii           28
# 7611  police investigating ebike collided car little...          135
# 7612  latest homes razed northern california wildfir...           68
#
#          mean_word_length  vowels_count  short_words_count  stopwords_count  \
# 7608                 5.10            19                  2                2
# 7609                 4.81            39                  8                9
# 7610                 3.14             9                  5                3
# 7611                 5.18            49                  7                5
# 7612                 5.27            21                  3                3
#
#       words_count
# 7608           10
# 7609           21
# 7610            7
# 7611           22
# 7612           11

# %%
train_test_data = train_data.append(test_data, ignore_index=True)
train_test_data['clean_text'].fillna(" ", inplace=True)

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(train_test_data.clean_text)
tf_idf = pd.DataFrame(data = X.toarray(), columns=vectorizer.get_feature_names())
tf_idf
# Out:
#                         aa                  aaa               aaaaaa  \
# 0                     0.00                 0.00                 0.00
# 1                     0.00                 0.00                 0.00
# 2                     0.00                 0.00                 0.00
# 3                     0.00                 0.00                 0.00
# 4                     0.00                 0.00                 0.00
# ...                    ...                  ...                  ...
# 10871                 0.00                 0.00                 0.00
# 10872                 0.00                 0.00                 0.00
# 10873                 0.00                 0.00                 0.00
# 10874                 0.00                 0.00                 0.00
# 10875                 0.00                 0.00                 0.00
#
#                     aaaand               aaalll          aaarrrgghhh  \
# 0                     0.00                 0.00                 0.00
# 1                     0.00                 0.00                 0.00
# 2                     0.00                 0.00                 0.00
# 3                     0.00                 0.00                 0.00
# 4                     0.00                 0.00                 0.00
# ...                    ...                  ...                  ...
# 10871                 0.00                 0.00                 0.00
# 10872                 0.00                 0.00                 0.00
# 10873                 0.00                 0.00                 0.00
# 10874                 0.00                 0.00                 0.00
# 10875                 0.00                 0.00                 0.00
#
#                       aabn        aaemiddleaged                  aal  \
# 0                     0.00                 0.00                 0.00
# 1                     0.00                 0.00                 0.00
# 2                     0.00                 0.00                 0.00
# 3                     0.00                 0.00                 0.00
# 4                     0.00                 0.00                 0.00
# ...                    ...                  ...                  ...
# 10871                 0.00                 0.00                 0.00
# 10872                 0.00                 0.00                 0.00
# 10873                 0.00                 0.00                 0.00
# 10874                 0.00                 0.00                 0.00
# 10875                 0.00                 0.00                 0.00
#
#                        aan  ...                zotar                zouis  \
# 0                     0.00  ...                 0.00                 0.00
# 1                     0.00  ...                 0.00                 0.00
# 2                     0.00  ...                 0.00                 0.00
# 3                     0.00  ...                 0.00                 0.00
# 4                     0.00  ...                 0.00                 0.00
# ...                    ...  ...                  ...                  ...
# 10871                 0.00  ...                 0.00                 0.00
# 10872                 0.00  ...                 0.00                 0.00
# 10873                 0.00  ...                 0.00                 0.00
# 10874                 0.00  ...                 0.00                 0.00
# 10875                 0.00  ...                 0.00                 0.00
#
#                      zouma                 zrnf                  zss  \
# 0                     0.00                 0.00                 0.00
# 1                     0.00                 0.00                 0.00
# 2                     0.00                 0.00                 0.00
# 3                     0.00                 0.00                 0.00
# 4                     0.00                 0.00                 0.00
# ...                    ...                  ...                  ...
# 10871                 0.00                 0.00                 0.00
# 10872                 0.00                 0.00                 0.00
# 10873                 0.00                 0.00                 0.00
# 10874                 0.00                 0.00                 0.00
# 10875                 0.00                 0.00                 0.00
#
#                       zuma               zumiez               zurich  \
# 0                     0.00                 0.00                 0.00
# 1                     0.00                 0.00                 0.00
# 2                     0.00                 0.00                 0.00
# 3                     0.00                 0.00                 0.00
# 4                     0.00                 0.00                 0.00
# ...                    ...                  ...                  ...
# 10871                 0.00                 0.00                 0.00
# 10872                 0.00                 0.00                 0.00
# 10873                 0.00                 0.00                 0.00
# 10874                 0.00                 0.00                 0.00
# 10875                 0.00                 0.00                 0.00
#
#                         zx                  zzz
# 0                     0.00                 0.00
# 1                     0.00                 0.00
# 2                     0.00                 0.00
# 3                     0.00                 0.00
# 4                     0.00                 0.00
# ...                    ...                  ...
# 10871                 0.00                 0.00
# 10872                 0.00                 0.00
# 10873                 0.00                 0.00
# 10874                 0.00                 0.00
# 10875                 0.00                 0.00
#
# [10876 rows x 17674 columns]

# %%
tf_idf_featured = pd.concat([train_test_data, tf_idf], axis=1)
tf_idf_featured
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-b92ec0c2c208> in <module>
# ----> 1 tf_idf_featured = pd.concat([train_test_data, tf_idf], axis=1)
#       2 tf_idf_featured.info()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282     )
#     283
# --> 284     return op.get_result()
#     285
#     286
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     495
#     496             new_data = concatenate_block_managers(
# --> 497                 mgrs_indexers, self.new_axes, concat_axis=self.axis, copy=self.copy
#     498             )
#     499             if not self.copy:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/internals/managers.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    2010             values = b.values
#    2011             if copy:
# -> 2012                 values = values.copy()
#    2013             else:
#    2014                 values = values.view()
#
# MemoryError:

# %%
tf_idf_featured.drop(['index', 'id_original', 'text_original', 'clean_text', 'keyword_original', 'location_original', 'hashtags', 'labels'], axis=1, inplace=True)

# %%
train = tf_idf_featured[:7613]
test = tf_idf_featured[7613:]

# %%
train
# Out:
#       id_original keyword_original location_original  \
# 0               1              NaN               NaN
# 1               4              NaN               NaN
# 2               5              NaN               NaN
# 3               6              NaN               NaN
# 4               7              NaN               NaN
# ...           ...              ...               ...
# 7608        10869              NaN               NaN
# 7609        10870              NaN               NaN
# 7610        10871              NaN               NaN
# 7611        10872              NaN               NaN
# 7612        10873              NaN               NaN
#
#                                           text_original         target_label  \
# 0     our deeds are the reason of this earthquake ma...                 1.00
# 1                 forest fire near la ronge sask canada                 1.00
# 2     all residents asked to shelter in place are be...                 1.00
# 3     people receive wildfires evacuation orders in ...                 1.00
# 4     just got sent this photo from ruby alaska as s...                 1.00
# ...                                                 ...                  ...
# 7608  two giant cranes holding  bridge collapse into...                 1.00
# 7609  aria ahrary thetawniest the out of control wil...                 1.00
# 7610                          utc km  of volcano hawaii                 1.00
# 7611  police investigating after an  bike collided w...                 1.00
# 7612  the latest more homes razed by northern califo...                 1.00
#
#       special_chars_count             hashtags                      labels  \
# 0                       1         #earthquake                          NaN
# 1                       1                  NaN                         NaN
# 2                       3                  NaN                         NaN
# 3                       2          #wildfires                          NaN
# 4                       2  #alaska #wildfires                          NaN
# ...                   ...                  ...                         ...
# 7608                    5                  NaN                         NaN
# 7609                    5                  NaN  @aria_ahrary @thetawniest
# 7610                   11                  NaN                         NaN
# 7611                    5                  NaN                         NaN
# 7612                    7                  NaN                         NaN
#
#       hashtags_count  labels_count  num_chars_count  links_count  \
# 0                  1             0                0            0
# 1                  0             0                0            0
# 2                  0             0                0            0
# 3                  1             0                5            0
# 4                  2             0                0            0
# ...              ...           ...              ...          ...
# 7608               0             0                1            1
# 7609               0             2                1            0
# 7610               0             0                9            1
# 7611               0             0                0            0
# 7612               0             0                2            1
#
#                                              clean_text  text_length  \
# 0          deeds reason earthquake may allah forgive us           68
# 1                 forest fire near la ronge sask canada           37
# 2     residents asked shelter place notified officer...          130
# 3     people receive wildfires evacuation orders cal...           56
# 4     got sent photo ruby alaska smoke wildfires pou...           85
# ...                                                 ...          ...
# 7608  two giant cranes holding bridge collapse nearb...           60
# 7609  control wild fires california even northern pa...          121
# 7610                              utc km volcano hawaii           28
# 7611  police investigating ebike collided car little...          135
# 7612  latest homes razed northern california wildfir...           68
#
#          mean_word_length  vowels_count  short_words_count  stopwords_count  \
# 0                    4.31            25                  7                6
# 1                    4.43            13                  1                0
# 2                    4.95            45                  9               11
# 3                    7.14            24                  1                1
# 4                    4.38            25                  3                7
# ...                   ...           ...                ...              ...
# 7608                 5.10            19                  2                2
# 7609                 4.81            39                  8                9
# 7610                 3.14             9                  5                3
# 7611                 5.18            49                  7                5
# 7612                 5.27            21                  3                3
#
#       words_count
# 0              13
# 1               7
# 2              22
# 3               7
# 4              16
# ...           ...
# 7608           10
# 7609           21
# 7610            7
# 7611           22
# 7612           11
#
# [7613 rows x 19 columns]

# %%
test
# Out:
#        id_original keyword_original location_original  \
# 7613             0              NaN               NaN
# 7614             2              NaN               NaN
# 7615             3              NaN               NaN
# 7616             9              NaN               NaN
# 7617            11              NaN               NaN
# ...            ...              ...               ...
# 10871        10861              NaN               NaN
# 10872        10865              NaN               NaN
# 10873        10868              NaN               NaN
# 10874        10874              NaN               NaN
# 10875        10875              NaN               NaN
#
#                                            text_original         target_label  \
# 7613                   just happened  terrible car crash                  nan
# 7614   heard about earthquake is different cities sta...                  nan
# 7615   there is  forest fire at spot pond geese are f...                  nan
# 7616               apocalypse lighting spokane wildfires                  nan
# 7617          typhoon soudelor kills in china and taiwan                  nan
# ...                                                  ...                  ...
# 10871  earthquake safety los angeles uo safety fasten...                  nan
# 10872  storm in ri worse than last hurricane my city ...                  nan
# 10873                   green line derailment in chicago                  nan
# 10874           meg issues hazardous weather outlook hwo                  nan
# 10875  cityofcalgary has activated its municipal emer...                  nan
#
#        special_chars_count                   hashtags labels  hashtags_count  \
# 7613                     0                        NaN    NaN               0
# 7614                     3               #earthquake     NaN               1
# 7615                     2                        NaN    NaN               0
# 7616                     3       #spokane #wildfires     NaN               2
# 7617                     0                        NaN    NaN               0
# ...                    ...                        ...    ...             ...
# 10871                    3                        NaN    NaN               0
# 10872                    5                        NaN    NaN               0
# 10873                    5                        NaN    NaN               0
# 10874                    7                        NaN    NaN               0
# 10875                    3  #cityofcalgary #yycstorm     NaN               2
#
#        labels_count  num_chars_count  links_count  \
# 7613              0                0            0
# 7614              0                0            0
# 7615              0                0            0
# 7616              0                0            0
# 7617              0                2            0
# ...             ...              ...          ...
# 10871             0                2            0
# 10872             0                6            0
# 10873             0                0            1
# 10874             0                3            1
# 10875             0                0            0
#
#                                               clean_text  text_length  \
# 7613                         happened terrible car crash           34
# 7614   heard earthquake different cities stay safe ev...           61
# 7615   forest fire spot pond geese fleeing across str...           94
# 7616               apocalypse lighting spokane wildfires           37
# 7617                 typhoon soudelor kills china taiwan           42
# ...                                                  ...          ...
# 10871  earthquake safety los angeles uo safety fasten...           54
# 10872  storm ri worse last hurricane city others hard...          130
# 10873                      green line derailment chicago           32
# 10874           meg issues hazardous weather outlook hwo           40
# 10875  cityofcalgary activated municipal emergency pl...           65
#
#           mean_word_length  vowels_count  short_words_count  stopwords_count  \
# 7613                  4.83            10                  2                2
# 7614                  5.89            24                  1                2
# 7615                  4.00            31                  7                9
# 7616                  8.50            12                  0                0
# 7617                  5.14            14                  2                2
# ...                    ...           ...                ...              ...
# 10871                 5.88            18                  2                0
# 10872                 4.24            36                  9                6
# 10873                 5.60            12                  1                1
# 10874                 5.83            16                  2                0
# 10875                 7.25            19                  2                2
#
#        words_count
# 7613             6
# 7614             9
# 7615            19
# 7616             4
# 7617             7
# ...            ...
# 10871            8
# 10872           25
# 10873            5
# 10874            6
# 10875            8
#
# [3263 rows x 19 columns]

# %%
clf = MultinomialNB()
clf.fit(train.drop(['target_label'], axis=1), train.target_label)

# %%
predicted = clf.predict(test.drop(['target_label'], axis=1))
